# %% [markdown]
# # Runs Community Assembley Models: Neutral and Selection
# Combines code from Neufit to run neutral modles as well as Gillespie simulation for selection models

# %% [markdown]
# ### Imports

# %%
import os
os.getcwd()

# %matplotlib inline
import matplotlib

from python_scripts.neufit import *

# %% [markdown]
# ### Datatypes

# %% [markdown]
# ### EAC
# From ICGC, not exact paper

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('EAC_species_WOL')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: 4b29da43-c844-4a95-b188-e54ff64b3529>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(411968, 'EAC_species_WOL')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %%
neufit_main(500000,'EAC_species_WOL')#200000,'EAC_species_WOL')
# Out:
#                                                     14521.04a446c6a660694dafe43ccaf1db7162  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       0
#
#                                                     14521.006cdcd42d55e07a2fd1ad2d31dd1a87  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       1
#
#                                                     14521.0337efea9b59b88f804ea384c356377c  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                                       0
# ...

# %% [markdown]
# ### Normal/Healthy & GERD Esoph Brushings
# Deshpande, N. P., Riordan, S. M., Castaño-Rodríguez, N., Wilkins, M. R. & Kaakoush, N. O. Signatures within the esophageal microbiome are associated with host genetics, age, and disease. Microbiome vol. 6 (2018) https://doi.org/10.1186/s40168-018-0611-4

# %% [markdown]
# #### WOL Species

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('Normal_species_WOL')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: 8db2bcb1-7e3f-4b01-8c1f-a1dba3e2f3df>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(270680, 'Normal_species_WOL')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('GERD_species_WOL')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: f46a955e-f179-4f57-93f1-7dc0b1706cd9>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(293307, 'GERD_species_WOL')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %% [markdown]
# ##### Normal / Healthy Esophgous

# %%
neufit_main(25000,'Normal_species_WOL') #50000,'Normal_species_WOL')
# Out:
#                                                     14458.ERR2373139  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373140  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373058  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373061  \
# ...

# %% [markdown]
# ##### GERD

# %%
neufit_main(25000, 'GERD_species_WOL')#50000,'GERD_species_WOL')
# Out:
#                                                     14458.ERR2373132  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373099  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373141  \
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Bacilla...                 0
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...                 0
# k__Bacteria;p__Proteobacteria;c__Gammaproteobac...                 0
#
#                                                     14458.ERR2373059  \
# ...

# %% [markdown]
# ### From Sam: Barrett's Esophgous Progressors/Non Progressors: using MetaPhlan4
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# #### MetaPhan4 Species - Estimated Counts

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('BE_species_MP_counts')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: b13c3bce-4a34-48bc-b98d-efde977e5df9>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(8625, 'BE_species_MP_counts')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %% [markdown]
# ##### Barrett's Esophgous

# %%
neufit_main(800,'BE_species_MP_counts')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1064.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1099.BE.01  14598.PCGA.1083.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1083.BE.02  14598.PCGA.1067.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors

# %%
neufit_main(800,'BE_NP_species_MP_counts')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1064.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1083.BE.01  14598.PCGA.1083.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1067.BE.01  14598.PCGA.1068.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors

# %%
neufit_main(800,'BE_Prog_species_MP_counts')
# Out:
#                        14598.PCGA.1099.BE.01  14598.PCGA.1116.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1088.BE.01  14598.PCGA.1088.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1069.BE.02  14598.PCGA.1108.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1073.BE.01  14598.PCGA.1073.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
neufit_main(800,'BE_NP_T1_species_MP_counts')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1083.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1067.BE.01  14598.PCGA.1068.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1070.BE.01  14598.PCGA.1110.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T2

# %%
neufit_main(800,'BE_NP_T2_species_MP_counts')
# Out:
#                        14598.PCGA.1064.BE.03  14598.PCGA.1083.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1068.BE.03  14598.PCGA.1068.BE.04  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1098.BE.02  14598.PCGA.1098.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1119.BE.03  14598.PCGA.1103.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
neufit_main(800,'BE_Prog_T1_species_MP_counts')
# Out:
#                        14598.PCGA.1088.BE.01  14598.PCGA.1073.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1074.BE.01  14598.PCGA.1074.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1135.BE.01  14598.PCGA.1135.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1139.BE.01  14598.PCGA.1089.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %%
neufit_main(800,'BE_Prog_T2_species_MP_counts')
# Out:
#                        14598.PCGA.1099.BE.01  14598.PCGA.1116.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1088.BE.03  14598.PCGA.1069.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1108.BE.01  14598.PCGA.1073.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1073.BE.04  14598.PCGA.1074.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# #### MetaPhan4 Species - Relative Abudances

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('BE_species_MP')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: da4e18fa-675c-4a41-b618-a19459ecc3ab>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(217, 'BE_species_MP')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %% [markdown]
# ##### Barrett's Esophgous

# %%
neufit_main(50,'BE_species_MP')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1064.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1099.BE.01  14598.PCGA.1083.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1083.BE.02  14598.PCGA.1067.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors

# %%
neufit_main(50,'BE_NP_species_MP')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1064.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1083.BE.01  14598.PCGA.1083.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1067.BE.01  14598.PCGA.1068.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors

# %%
neufit_main(50,'BE_Prog_species_MP')
# Out:
#                        14598.PCGA.1099.BE.01  14598.PCGA.1116.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1088.BE.01  14598.PCGA.1088.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1069.BE.02  14598.PCGA.1108.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1073.BE.01  14598.PCGA.1073.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
neufit_main(50,'BE_NP_T1_species_MP')
# Out:
#                        14598.PCGA.1123.BE.01  14598.PCGA.1064.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1064.BE.02  14598.PCGA.1083.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1067.BE.01  14598.PCGA.1068.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1070.BE.01  14598.PCGA.1110.BE.01  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T2

# %%
neufit_main(50,'BE_NP_T2_species_MP')
# Out:
#                        14598.PCGA.1064.BE.03  14598.PCGA.1083.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1068.BE.03  14598.PCGA.1068.BE.04  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1098.BE.02  14598.PCGA.1098.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1119.BE.03  14598.PCGA.1103.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
neufit_main(50,'BE_Prog_T1_species_MP')
# Out:
#                        14598.PCGA.1088.BE.01  14598.PCGA.1073.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1074.BE.01  14598.PCGA.1074.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1135.BE.01  14598.PCGA.1135.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1139.BE.01  14598.PCGA.1089.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %%
neufit_main(50,'BE_Prog_T2_species_MP')
# Out:
#                        14598.PCGA.1099.BE.01  14598.PCGA.1116.BE.01  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1088.BE.03  14598.PCGA.1069.BE.02  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1108.BE.01  14598.PCGA.1073.BE.03  \
# Abiotrophia_defectiva                      0                      0
# Actinomyces_SGB17154                       0                      0
# Actinomyces_SGB17168                       0                      0
#
#                        14598.PCGA.1073.BE.04  14598.PCGA.1074.BE.03  \
# Abiotrophia_defectiva                      0                      0
# ...

# %% [markdown]
# ### Barrett's Esophgous Progressors/Non Progressors
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# ##### WOL Species

# %%
#Only need to run the first time to see what to put into plot below
table_summary = calculate_summary_table('BE_species_WOL')
table_summary.visualization
# Out:
# <visualization: Visualization uuid: 7a3358ce-d6a9-489a-9860-0b58a8fbd526>

# %%
#Only need to run the first time to see what to put into plot below
alpha_rare = calculate_rarefaction(75733, 'BE_species_WOL')
alpha_rare.visualization
# Out:
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_alpha/_visualizer.py:245: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_ = grouped.median()
# ...

# %% [markdown]
# ##### Barrett's Esophgous

# %%
neufit_main(25000,'BE_species_WOL')
# Out:
#                                                     14598.PCGA.1087.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1068.BE.01  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1092.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors

# %%
neufit_main(25000,'BE_NP_species_WOL')
# Out:
#                                                     14598.PCGA.1087.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1068.BE.01  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1143.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors

# %%
neufit_main(25000,'BE_Prog_species_WOL')
# Out:
#                                                     14598.PCGA.1092.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1091.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1099.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
neufit_main(25000,'BE_NP_T1_species_WOL')
# Out:
#                                                     14598.PCGA.1087.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1068.BE.01  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1143.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T2

# %%
neufit_main(250000,'BE_NP_T2_species_WOL')
# Out:
#                                                     14598.PCGA.1104.BE.01  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1095.BE.04  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1070.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %%
neufit_main(80000,'BE_NP_T2_species_WOL')
# Out:
#                                                     14598.PCGA.1104.BE.01  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1095.BE.04  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1070.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
neufit_main(25000,'BE_Prog_T1_species_WOL')
# Out:
#                                                     14598.PCGA.1092.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1091.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1099.BE.02  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %%
neufit_main(25000,'BE_Prog_T2_species_WOL')
# Out:
#                                                     14598.PCGA.1140.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1102.BE.03  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
#                                                     14598.PCGA.1139.BE.04  \
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
# k__Archaea;p__Euryarchaeota;c__Halobacteria;o__...                      0
#
# ...

# %% [markdown]
# ### Normal Blood, BE & EAC Tissue
# Ross-Innes, C. S. et al. Whole-genome sequencing provides new insights into the clonal architecture of Barrett’s esophagus and esophageal adenocarcinoma. Nature Genetics vol. 47 1038–1046 (2015) https://doi.org/10.1038/ng.3357

# %% [markdown]
# ##### Paired (R1&R2), orginal, what everything else is standardized to

# %% [markdown]
# ##### BE

# %%
#Only need to run the first time to determine which rarefaction level should be used

table_summary = calculate_summary_table('BE_Ross_paired_species_WOL')

table_summary.visualization

# %%
neufit_main(2000000,'BE_Ross_paired_species_WOL')
# Out:
#                                                     Barretts_17_EGAF00000814884  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            2
#
#                                                     Barretts_12_EGAF00000525202  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
#
#                                                     Barretts_4_EGAF00000814870  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           1
#
# ...

# %%
neufit_main(2000000,'BE_exact_Ross_paired_species_WOL')
# Out:
#                                                     Barretts_12_EGAF00000525202  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
#
#                                                     Barretts_19_EGAF00000530863  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
#
#                                                     Barretts_6_EGAF00000560127  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           1
#
# ...

# %%
neufit_main(2000000,'BE_Ross_paired_genome_WOL')
# Out:
#             Barretts_17_EGAF00000814884  Barretts_12_EGAF00000525202  \
# G000005825                            0                            0
# G000006605                            0                            0
# G000006725                            0                            0
#
#             Barretts_4_EGAF00000814870  Barretts_17_EGAF00000814883  \
# G000005825                           0                            0
# G000006605                           0                            0
# G000006725                           0                            0
#
#             Barretts_19_EGAF00000530863  Barretts_6_EGAF00000560127  \
# G000005825                            0                           0
# G000006605                            0                           0
# G000006725                            0                           0
#
#             Barretts_22_EGAF00000525458  Barretts_23_EGAF00000501983  \
# ...

# %%
#rarefy to consistent level just to see how results are effected
neufit_main(25000,'BE_Ross_paired_species_WOL')
# Out:
#                                                     Barretts_17_EGAF00000814884  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            2
#
#                                                     Barretts_12_EGAF00000525202  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
#
#                                                     Barretts_4_EGAF00000814870  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           1
#
# ...

# %% [markdown]
# ##### EAC

# %%
neufit_main(2000000,'EAC_Ross_paired_species_WOL')
# Out:
#                                                     Tumor_13_EGAF00000525466  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         3
#
#                                                     Tumor_4_EGAF00000814885  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        1
#
#                                                     Tumor_8_EGAF00000814887  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        1
#
# ...

# %%
neufit_main(2000000,'EAC_exact_Ross_paired_species_WOL')
# Out:
#                                                     Tumor_13_EGAF00000525466  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         3
#
#                                                     Tumor_17_EGAF00000525479  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         2
#
#                                                     Tumor_1_EGAF00000501976  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
#
# ...

# %%
#rarefy to consistent level just to see how results are effected
neufit_main(25000,'EAC_Ross_paired_species_WOL')
# Out:
#                                                     Tumor_13_EGAF00000525466  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         3
#
#                                                     Tumor_4_EGAF00000814885  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        1
#
#                                                     Tumor_8_EGAF00000814887  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        1
#
# ...

# %% [markdown]
# ##### Normal Blood

# %%
neufit_main(1000000,'Norm_Ross_paired_species_WOL')

# %% [markdown]
# ##### Combo (R1&R2, R1, R2) & Unpaired (R1, R2)

# %% [markdown]
# ###### BE

# %%
#Only need to run the first time to determine which rarefaction level should be used

table_summary = calculate_summary_table('BE_Ross_combo_species_WOL')

'''Alpha diversity taking too long to run here, so ran command on cluster
alpha_rare = calculate_rarefaction(9000000, 'ALL_Ross_combo_species_WOL')
alpha_rare.visualization
'''

table_summary.visualization
# Out:
# <visualization: Visualization uuid: ba375110-60da-4fe0-a4ae-e1e5c95b5173>

# %% [markdown]
# Qiime2 view:
# ![image.png](attachment:501c28ce-9257-4415-8202-d88faed29888.png)

# %%
neufit_main(70000000,'BE_Ross_combo_species_WOL')
# Out:
#                                                     Barretts_17_EGAF00000814884  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            3
#
#                                                     Barretts_12_EGAF00000525202  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            3
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
#
#                                                     Barretts_4_EGAF00000814870  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           2
#
# ...

# %%
neufit_main(1000000,'BE_Ross_unpaired_species_WOL')
# Out:
#                                                     Barretts_17_EGAF00000814884  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            2
#
#                                                     Barretts_12_EGAF00000525202  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            2
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                            1
#
#                                                     Barretts_4_EGAF00000814870  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                           1
#
# ...

# %% [markdown]
# ###### EAC

# %%
neufit_main(1000000,'EAC_Ross_combo_species_WOL')
# Out:
#                                                     Tumor_13_EGAF00000525466  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                         5
#
#                                                     Tumor_4_EGAF00000814885  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        2
#
#                                                     Tumor_8_EGAF00000814887  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                        2
#
# ...

# %% [markdown]
# ###### Normal

# %%
neufit_main(1000000,'Norm_Ross_combo_species_WOL')
# Out:
#                                                     Normal_13_EGAF00000525440  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          2
#
#                                                     Normal_17_EGAF00000525444  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          1
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          2
#
#                                                     Normal_23_EGAF00000501973  \
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          0
# k__Archaea;p__Crenarchaeota;c__Thermoprotei;o__...                          0
#
# ...
