# %% [markdown]
# ## Alpha/Beta Diversity for EAC Progresson
# Date: 10/25/2024
# Goal: Create alpha and beta diversity metrics for paper
#
# Conda (local & in notebook): comad_EAC_figures - then figures will show

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

from python_scripts.alpha_beta import *

# %% [markdown]
# ### Create Figures

# %% [markdown]
# #### Figure 2A - Basic Alpha Diversity - Shannon
# NOTE: must change qza to zip and unzip in order to get this to run on new dataset

# %% [markdown]
# ##### Dataset Unquie Rarefaction

# %%
#Creates qza file of Alpha - shannon
alpha_output, = multi_basic_alpha(['normal_species_WOL_scrubbed_micov-paper11-20-24_r80000', 'GERD_species_WOL_scrubbed_micov-paper11-20-24_r80000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000',
                                 'EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24_r150000', 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24_r150000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper11-20-24', 'shannon')
alpha_output
# Out:
# <visualization: Visualization uuid: 24380075-ce9c-4ffa-a080-e7ad7fa2618f>

# %%
### Creates pretty plot of Alpha - shannon 
alpha_plot('Paper-Progression_WOL_scrubbed_micov_paper11-20-24', metric='shannon')

# %%
#Create alpha diversity stats referenced in paper
alphaPaperStats('Paper-Progression_WOL_scrubbed_micov_paper11-20-24')
# Out:
#                           id  \
# 0           14458.ERR2373136
# 1           14458.ERR2373134
# 2           14458.ERR2373127
# 3           14458.ERR2373125
# 4           14458.ERR2373124
# ..                       ...
# 272  Tumor_4_EGAF00000525476
# 273  Tumor_5_EGAF00000525478
# 274  Tumor_6_EGAF00000560171
# 275  Tumor_8_EGAF00000525467
# 276  Tumor_9_EGAF00000525188
#
#                                            study_label  observed_features
# 0    normal_species_WOL_scrubbed_micov-paper11-20-2...                347
# 1    normal_species_WOL_scrubbed_micov-paper11-20-2...                287
# 2    normal_species_WOL_scrubbed_micov-paper11-20-2...                326
# 3    normal_species_WOL_scrubbed_micov-paper11-20-2...                347
# 4    normal_species_WOL_scrubbed_micov-paper11-20-2...                265
# ..                                                 ...                ...
# 272  EAC_Ross_species_WOL_scrubbed_micov-paper11-20...                 95
# ...

# %% [markdown]
# ##### (Not currently in manuscript) 14,000 Rarefaction

# %%
#Creates qza file of Alpha - shannon
alpha_output, = multi_basic_alpha(['normal_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'GERD_species_WOL_scrubbed_micov-paper10-28-24_r14000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000',
                                 'EAC_Ross_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'EAC_ICGC_species_WOL_scrubbed_micov-paper10-28-24_r14000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper10-28-24_r14000', 'shannon')
alpha_output
# Out:
# <visualization: Visualization uuid: 55bac8fb-6ce9-4a86-adf7-7a49b1efaf49>

# %%
### Creates pretty plot of Alpha - shannon 
alpha_plot('Paper-Progression_WOL_scrubbed_micov_paper10-28-24_r14000', metric='shannon')

# %% [markdown]
# #### Figure 2B - Basic Alpha Diversity - Observed

# %% [markdown]
# ##### Dataset Unquie Rarefaction

# %%
#Creates qza file of Alpha - observed
alpha_output, = multi_basic_alpha(['normal_species_WOL_scrubbed_micov-paper11-20-24_r80000', 'GERD_species_WOL_scrubbed_micov-paper11-20-24_r80000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000',
                                 'EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24_r150000', 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24_r150000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper11-20-24')
alpha_output
# Out:
# <visualization: Visualization uuid: 244bf12e-e1fd-437e-81aa-5cd91908614f>

# %%
### Creates pretty plot of Alpha - observed 
alpha_plot('Paper-Progression_WOL_scrubbed_micov_paper11-20-24')

# %% [markdown]
# ##### (Not currently in manuscript) 14,000 Rarefaction

# %%
#Creates qza file of Alpha - observed
alpha_output, = multi_basic_alpha(['normal_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'GERD_species_WOL_scrubbed_micov-paper10-28-24_r14000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000',
                                 'EAC_Ross_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'EAC_ICGC_species_WOL_scrubbed_micov-paper10-28-24_r14000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper10-28-24_r14000')
alpha_output
# Out:
# <visualization: Visualization uuid: f2d810bf-7b69-498d-ae31-159647b4c528>

# %%
### Creates pretty plot of Alpha - observed 
alpha_plot('Paper-Progression_WOL_scrubbed_micov_paper10-28-24_r14000')

# %% [markdown]
# #### Figure 2C - RPCA Beta Diversity

# %% [markdown]
# ##### Rarefied by dataset

# %%
rpca_biplot_emperor_v, rpca_beta_result_d = beta_decoide(['normal_species_WOL_scrubbed_micov-paper11-20-24_r80000', 'GERD_species_WOL_scrubbed_micov-paper11-20-24_r80000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000',
                                 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24_r150000', 'EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24_r150000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper11-20-24')
rpca_biplot_emperor_v
# Out:
# Saved PCoAResults % Properties('biplot') to: deicode_biplot.qza
# Saved DistanceMatrix to: deicode_distance_test.qza
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ...

# %%
rpca_beta_result_d
# Out:
# <visualization: Visualization uuid: 67cfa3dc-3f2a-4dce-8fcb-67bb9eec29d0>

# %% [markdown]
# ##### (not used in manuscript) Unrarfied

# %%
rpca_biplot_emperor_v, rpca_beta_result_d = beta_decoide(['normal_species_WOL_scrubbed_micov-paper10-28-24', 'GERD_species_WOL_scrubbed_micov-paper10-28-24',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24',
                                 'EAC_Ross_species_WOL_scrubbed_micov-paper10-28-24', 'EAC_ICGC_species_WOL_scrubbed_micov-paper10-28-24'],
                                'Paper-Progression_WOL_scrubbed_micov_paper10-28-24_ur')
rpca_biplot_emperor_v
# Out:
# Saved PCoAResults % Properties('biplot') to: deicode_biplot.qza
# Saved DistanceMatrix to: deicode_distance_test.qza
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ...

# %%
rpca_beta_result_d
# Out:
# <visualization: Visualization uuid: 651b929b-5177-46ea-a8d9-3d02bf90535b>

# %% [markdown]
# ##### (not used in manuscript) Rarfied to 14,000

# %%
rpca_biplot_emperor_v, rpca_beta_result_d = beta_decoide(['normal_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'GERD_species_WOL_scrubbed_micov-paper10-28-24_r14000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000',
                                 'EAC_Ross_species_WOL_scrubbed_micov-paper10-28-24_r14000', 'EAC_ICGC_species_WOL_scrubbed_micov-paper10-28-24_r14000'],
                                'Paper-Progression_WOL_scrubbed_micov_paper10-28-24_r14000')
rpca_biplot_emperor_v
# Out:
# Saved PCoAResults % Properties('biplot') to: deicode_biplot.qza
# Saved DistanceMatrix to: deicode_distance_test.qza
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/cguccion/miniconda3/envs/comad_EAC_figures/lib/python3.8/site-packages/q2_diversity/_beta/_visualizer.py:193: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ...

# %%
rpca_beta_result_d
# Out:
# <visualization: Visualization uuid: da66b413-be13-4681-832b-c74bc8b49595>

# %% [markdown]
# #### Supp. Figure 4 - Phlya Level Taxonomy barplots

# %%
taxa_barplots = multi_taxonomy_barplot(['normal_none_WOL_scrubbed_micov-paper11-20-24_r80000', 'GERD_none_WOL_scrubbed_micov-paper11-20-24_r80000',
                                 'BE_NP_T1_none_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000', 'BE_Prog_T1_none_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000',
                                 'EAC_Ross_none_WOL_scrubbed_micov-paper11-20-24_r150000', 'EAC_ICGC_none_WOL_scrubbed_micov-paper11-20-24_r150000'],
                                   'phlaTaxa-Paper-Progression_WOL_none_scrubbed_micov_paper11-20-24')

taxa_barplots
# Out:
# <visualization: Visualization uuid: 2887c4a1-8419-4222-a4bb-4212c8fb7dfc>

# %% [markdown]
# #### Supp. Figure 8 - Alpha Rarefaction Curves

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24', 'normal_species_WOL_scrubbed_micov-paper11-20-24',
                                     'GERD_species_WOL_scrubbed_micov-paper11-20-24', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24', 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24'],
                                     'Paper-Progression_WOL_scrubbed_micov-11.20.24-r25000', max_depth=25000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 3288277d-920d-4425-8ea2-7cd3c075aeff>

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24', 'normal_species_WOL_scrubbed_micov-paper11-20-24',
                                     'GERD_species_WOL_scrubbed_micov-paper11-20-24', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24', 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24'],
                                     'Paper-Progression_WOL_scrubbed_micov-11.20.24-r450000', max_depth=450000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 6a2cc145-ac70-4f6c-a663-5081cf8ea164>

# %%
#Alpha Rare Curve

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov', 'normal_species_WOL_scrubbed_micov',
                                     'GERD_species_WOL_scrubbed_micov', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100', 'EAC_Ross_species_WOL_scrubbed_micov'],
                                     'Paper-Progression_WOL_scrubbed_micov-10.25.24-r150000', max_depth=150000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: c9956bfa-127c-4bbe-91a4-36359447ebc5>

# %%
#Alpha Rare Curve 

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov', 'normal_species_WOL_scrubbed_micov',
                                     'GERD_species_WOL_scrubbed_micov', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100', 'EAC_Ross_species_WOL_scrubbed_micov'],
                                     'Paper-Progression_WOL_scrubbed_micov-10.25.24-r300000', max_depth=300000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 1e9c92d7-6791-423a-af20-2f82475d53b0>

# %% [markdown]
# #### Supp. Figure 5 (Help) - Alpha Rarefaction Curves  for Metphlan

# %%
#Alpha Rare Curve to figure out Depth for Metaphlan

alpha_rare_output = multi_alpha_rare(['BE_NP_T1_species_MP_counts', 'BE_NP_T2_species_MP_counts', 'BE_Prog_T1_species_MP_counts',
                                     'BE_Prog_T2_species_MP_counts'],
                                     'metalphlan', max_depth=1000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 18fcd363-35fc-4a46-830c-21b3dadc7671>

# %%
#Alpha Rare Curve to figure out Depth for Metaphlan

alpha_rare_output = multi_alpha_rare(['BE_NP_T1_species_MP_counts', 'BE_NP_T2_species_MP_counts', 'BE_Prog_T1_species_MP_counts',
                                     'BE_Prog_T2_species_MP_counts'],
                                     'metalphlan', max_depth=5000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: abc970e5-1ba8-43bc-a39c-06ebc557470f>

# %%
#Alpha Rare Curve to figure out Depth for Metaphlan

alpha_rare_output = multi_alpha_rare(['BE_NP_T1_species_MP_counts', 'BE_NP_T2_species_MP_counts', 'BE_Prog_T1_species_MP_counts',
                                     'BE_Prog_T2_species_MP_counts'],
                                     'metalphlan', max_depth=15000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: ab6c1479-01d5-425a-aa7f-e17c5e4517e9>

# %%
#Alpha Rare Curve to figure out Depth for Metaphlan

alpha_rare_output = multi_alpha_rare(['BE_NP_T1_species_MP_counts', 'BE_NP_T2_species_MP_counts', 'BE_Prog_T1_species_MP_counts',
                                     'BE_Prog_T2_species_MP_counts'],
                                     'metalphlan', max_depth=30000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 63ccf08f-4336-48e9-a4b8-5d932ad46384>

# %% [markdown]
# #### Supp. Figure 10 (Help) - Alpha Rarefaction Curves  for Known Human

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov_kh', 'normal_species_WOL_scrubbed_micov_kh',
                                     'GERD_species_WOL_scrubbed_micov_kh', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_kh',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', 'EAC_Ross_species_WOL_scrubbed_micov_kh'],
                                     'Paper-Progression_WOL_scrubbed_micov_kh-10.25.24-r25000', max_depth=500)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 3cd725a5-74c7-4c8d-9363-32886eb53898>

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov_kh', 'normal_species_WOL_scrubbed_micov_kh',
                                     'GERD_species_WOL_scrubbed_micov_kh', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_kh',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', 'EAC_Ross_species_WOL_scrubbed_micov_kh'],
                                     'Paper-Progression_WOL_scrubbed_micov_kh-10.25.24-r25000', max_depth=2000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 801c62bf-9056-4d4e-89a5-c2493239d145>

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov_kh', 'normal_species_WOL_scrubbed_micov_kh',
                                     'GERD_species_WOL_scrubbed_micov_kh', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_kh',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', 'EAC_Ross_species_WOL_scrubbed_micov_kh'],
                                     'Paper-Progression_WOL_scrubbed_micov_kh-10.25.24-r25000', max_depth=8000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: e194dc26-559e-4de9-9bac-2c42b1a7a339>

# %%
#Alpha Rare Curve for Supplemental

alpha_rare_output = multi_alpha_rare(['EAC_ICGC_species_WOL_scrubbed_micov_kh', 'normal_species_WOL_scrubbed_micov_kh',
                                     'GERD_species_WOL_scrubbed_micov_kh', 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_kh',
                                     'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', 'EAC_Ross_species_WOL_scrubbed_micov_kh'],
                                     'Paper-Progression_WOL_scrubbed_micov_kh-10.25.24-r25000', max_depth=25000)
alpha_rare_output
# Out:
# <visualization: Visualization uuid: 282d439c-f823-47f1-b4d1-990a3ca96035>

# %% [markdown]
# #### Supp. Figure 8 Venn Diagrams

# %%
venn_digram_plot_(['normal_species_WOL_scrubbed_micov-paper11-20-24_r80000', 'GERD_species_WOL_scrubbed_micov-paper11-20-24_r80000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper11-20-24_r14000',
                                 'EAC_ICGC_species_WOL_scrubbed_micov-paper11-20-24_r150000', 'EAC_Ross_species_WOL_scrubbed_micov-paper11-20-24_r150000'],
                                   'Paper-Progression_WOL_none_scrubbed_micov_paper11-20-24')

# %%
create_upset_(['normal_species_WOL_scrubbed_micov-paper10-28-24_r80000', 'GERD_species_WOL_scrubbed_micov-paper10-28-24_r80000',
                                 'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000', 'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100-paper10-28-24_r14000',
                                 'EAC_ICGC_species_WOL_scrubbed_micov-paper10-28-24_r150000', 'EAC_Ross_species_WOL_scrubbed_micov-paper10-28-24_r150000'],
                                   'Paper-Progression_WOL_none_scrubbed_micov_paper11-20-24')
