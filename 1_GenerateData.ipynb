# %% [markdown]
# # Genearate Data
# Date: 10/15/2024
# Goal: Subset data following micov filtering to appropriate subgroups of metadata

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import qiime2 as q2
from qiime2.plugins import taxa

from python_scripts.import_split_biom import *

# %% [markdown]
# ### Datatypes

# %% [markdown]
# ### EAC ICGC
#
# "Pan-Cancer Analysis of Whole Genomes." Nature, vol. 578, no. 7793, 2020, pp. 82-93,  https://doi.org/10.1038/s41586-020-1969-6. Accessed 17 Jan. 2024.
# (Qiita: 14857)

# %%
#Micov
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed_micov', micov_filter='ICGC_all', rare_level=150000)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# ...

# %%
#Micov
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed_micov', micov_filter='ICGC_all', rare_level=14000)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# ...

# %%
#Micov + kH
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed_micov_kh', micov_filter='ICGC_all', keep_hu=True, rare_level=3000)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# ...

# %%
#Micov - genome level for taxonomy barplots
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_none_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_none_WOL_scrubbed_micov', micov_filter='ICGC_all', rare_level=150000)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# ...

# %%
#Micov - Male only 
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed_micov_MO', micov_filter='ICGC_all', rare_level=150000, sex_split=['male'])
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# ...

# %%
#Micov - Female only 
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed_micov_FO', micov_filter='ICGC_all', rare_level=150000, sex_split=['female'])
# Out:
#                                      sample_name  project  \
# 10  14857.14521.10e5754ff94f5da74a0d04bd57c744b0  ESAD-UK
# 19  14857.14521.2c0180436ed4e6909018a722255feb2d  ESAD-UK
# 25  14857.14521.34f750e775facce4468828b9f3a94a54  ESAD-UK
#
#                                          filename donor_sex project_code  \
# 10  10e5754ff94f5da74a0d04bd57c744b0.filtered.bam    female      ESAD-UK
# 19  2c0180436ed4e6909018a722255feb2d.filtered.bam    female      ESAD-UK
# 25  34f750e775facce4468828b9f3a94a54.filtered.bam    female      ESAD-UK
#
#    icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 10       DO50338       SA528908          unknown                NaN
# 19       DO50398       SA528864          unknown                NaN
# 25       DO50365       SA528896          unknown                NaN
#
#    donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 10              alive  ...                    80.0                    PCAWG
# ...

# %% [markdown]
# ### Normal/Healthy & GERD Esoph Brushings
# Deshpande, N. P., Riordan, S. M., Castaño-Rodríguez, N., Wilkins, M. R. & Kaakoush, N. O. Signatures within the esophageal microbiome are associated with host genetics, age, and disease. Microbiome vol. 6 (2018) https://doi.org/10.1186/s40168-018-0611-4

# %% [markdown]
# Other params (might use):  remove_reag, keep_hu

# %% [markdown]
# ##### Normal / Healthy Esophgous

# %%
#Micov
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=80000)
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL_scrubbed_micov-paper11-20-24  =  50
#                                                     14458.ERR2373139  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               2.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...               3.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               0.0
# ...

# %%
#Micov
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=14000)
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL_scrubbed_micov-paper10-28-24  =  50
#                                                     14458.ERR2373139  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               2.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...               3.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               0.0
# ...

# %%
#Micov + kH
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed_micov_kh', micov_filter='NormGerd', keep_hu=True, rare_level=15000)
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL_scrubbed_micov_kh-paper11-20-24  =  50
#                                                     14458.ERR2373139  \
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...               3.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               3.0
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...              55.0
# ...

# %%
#Micov - genome level for taxonomy barplots
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'normal_none_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=80000)
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_none_WOL_scrubbed_micov-paper11-20-24  =  50
#             14458.ERR2373139  14458.ERR2373140  14458.ERR2373058  \
# G000006605               0.0               0.0               0.0
# G000006785               2.0               7.0              37.0
# G000006845               3.0               9.0               5.0
# G000006865               0.0               1.0               8.0
# G000006925               2.0               0.0               0.0
# ...

# %%
#Micov - Male only
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed_micov_MO', micov_filter='NormGerd', rare_level=80000, sex_split=['M'])
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 3  14458.ERR2373127   49   NO      M     YES    Normal     H90_S80_SG
# 4  14458.ERR2373125   68  YES      M     YES    Normal     H88_S78_SG
# 5  14458.ERR2373124   59  YES      M     YES    Normal     H87_S77_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 3              NO                H90           14458
# 4              NO                H88           14458
# 5              NO                H87           14458
# Total number of samples in normal_species_WOL_scrubbed_micov_MO  =  18
#                                                     14458.ERR2373067  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               7.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              30.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...             114.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               4.0
# ...

# %%
#Micov - Feamle only
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed_micov_FO', micov_filter='NormGerd', rare_level=80000, sex_split=['F'])
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL_scrubbed_micov_FO  =  32
#                                                     14458.ERR2373139  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               2.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...               3.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               0.0
# ...

# %% [markdown]
# ##### GERD

# %%
#Micov
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=80000)
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_species_WOL_scrubbed_micov-paper11-20-24  =  29
#                                                     14458.ERR2373132  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               8.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              30.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               1.0
# ...

# %%
#Micov
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=14000)
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_species_WOL_scrubbed_micov-paper10-28-24  =  29
#                                                     14458.ERR2373132  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               8.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              30.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               1.0
# ...

# %%
#Micov + kH
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed_micov_kh', micov_filter='NormGerd', keep_hu=True, rare_level=15000)
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_species_WOL_scrubbed_micov_kh-paper11-20-24  =  29
#                                                     14458.ERR2373132  \
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              30.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               1.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              29.0
# k__Bacteria;p__Fusobacteria;c__Fusobacteriia;o_...             131.0
# ...

# %%
#Micov - genome level for taxonomy barplots
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'GERD_none_WOL_scrubbed_micov', micov_filter='NormGerd', rare_level=80000)
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_none_WOL_scrubbed_micov-paper11-20-24  =  29
#             14458.ERR2373132  14458.ERR2373099  14458.ERR2373141  \
# G000006605               0.0               0.0               0.0
# G000006785               8.0              11.0               2.0
# G000006845              30.0             111.0               7.0
# G000006865               1.0               3.0               0.0
# G000006925               1.0               0.0               0.0
# ...

# %%
#Micov - Male only
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed_micov_MO', micov_filter='NormGerd', rare_level=80000, sex_split=['M'])
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53   NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36   NO      M     YES      GERD     H97_S88_SG
# 5  14458.ERR2373126   47  YES      M     YES      GERD     H89_S79_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 5             YES                H89           14458
# Total number of samples in GERD_species_WOL_scrubbed_micov_MO  =  10
#                                                     14458.ERR2373099  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...              12.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...             111.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               3.0
# ...

# %%
#Micov - Female only
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed_micov_FO', micov_filter='NormGerd', rare_level=80000, sex_split=['F'])
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 2  14458.ERR2373132   34   NO      F     YES      GERD     H94_S85_SG
# 3  14458.ERR2373131   44   NO      F     YES      GERD     H93_S84_SG
# 4  14458.ERR2373130   42  YES      F     YES      GERD     H92_S83_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 2             YES                H94           14458
# 3             YES                H93           14458
# 4             YES                H92           14458
# Total number of samples in GERD_species_WOL_scrubbed_micov_FO  =  19
#                                                     14458.ERR2373132  \
# k__Bacteria;p__Actinobacteria;c__Actinobacteria...               0.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               8.0
# k__Bacteria;p__Proteobacteria;c__Betaproteobact...              30.0
# k__Bacteria;p__Firmicutes;c__Bacilli;o__Lactoba...               1.0
# ...

# %% [markdown]
# ### Barrett's Esophgous Progressors/Non Progressors
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
# Micov 
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# ...

# %%
#Micov + kH
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', micov_filter='BE_all_T2100_T3100', keep_hu=True, rare_level=50)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# ...

# %%
# Micov - genome level for taxonomy barplots
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_none_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# ...

# %%
# Micov - Male only 
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_MO', micov_filter='BE_all_T2100_T3100', rare_level=14000, sex_split=['M'])
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# ...

# %%
# Micov - Female only 
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed_micov_T2100_T3100_FO', micov_filter='BE_all_T2100_T3100', rare_level=14000, sex_split=['F'])
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# ...

# %% [markdown]
# ##### [Supplemental] Barrett's Esophgous Non Progressors T2

# %%
#Micov
be_data_split(['NP'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T2_species_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# ...

# %%
#Micov + kH
be_data_split(['NP'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T2_species_WOL_scrubbed_micov_T2100_T3100_kh', micov_filter='BE_all_T2100_T3100', keep_hu=True)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
#Micov
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# ...

# %%
#Micov + kH
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_kh', micov_filter='BE_all_T2100_T3100', keep_hu=True, rare_level=50)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# ...

# %%
#Micov - genome level for taxonomy barplots
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_none_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# ...

# %%
# Micov - Male only 
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_MO', micov_filter='BE_all_T2100_T3100', rare_level=14000, sex_split=['M'])
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# ...

# %%
# Micov - Female only 
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_species_WOL_scrubbed_micov_T2100_T3100_FO', micov_filter='BE_all_T2100_T3100', rare_level=14000, sex_split=['F'])
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# ...

# %% [markdown]
# ##### [Supplemental] Barrett's Esophgous Progressors T2

# %%
#Micov
be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T2_species_WOL_scrubbed_micov_T2100_T3100', micov_filter='BE_all_T2100_T3100', rare_level=14000)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# ...

# %%
#Micov + kH
be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T2_species_WOL_scrubbed_micov_T2100_T3100_kh', micov_filter='BE_all_T2100_T3100', keep_hu=True)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# ...

# %% [markdown]
# ### BE, EAC Tissue
# Ross-Innes, C. S. et al. Whole-genome sequencing provides new insights into the clonal architecture of Barrett’s esophagus and esophageal adenocarcinoma. Nature Genetics vol. 47 1038–1046 (2015) https://doi.org/10.1038/ng.3357. This also has normal tissue but we are not using it.
# Note: As a default now, only keeps the exact 23 samples that are acutally in Ross-Innes publication (Ginny_list)

# %% [markdown]
# ##### [Not in paper] BE

# %%
#Movi
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'BE_Ross_species_WOL_scrubbed')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            92.57
# 1  IIIC  Normal esophagus                     3.0  ...            93.50
# 2   IIB             Blood                     NaN  ...            93.01
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              339.0      5.30           0.245                   55.76
# ...

# %% [markdown]
# ##### EAC

# %%
#Micov
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_species_WOL_scrubbed_micov', micov_filter='Fitz_all', rare_level=150000)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            93.72
# 1  IIIC  Normal esophagus                     3.0  ...            93.70
# 2   IIB             Blood                     NaN  ...            93.33
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# ...

# %%
#Micov
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_species_WOL_scrubbed_micov', micov_filter='Fitz_all', rare_level=14000)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            93.72
# 1  IIIC  Normal esophagus                     3.0  ...            93.70
# 2   IIB             Blood                     NaN  ...            93.33
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# ...

# %%
#Micov + kH
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_species_WOL_scrubbed_micov_kh', micov_filter='Fitz_all', keep_hu=True, rare_level=3000)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            93.72
# 1  IIIC  Normal esophagus                     3.0  ...            93.70
# 2   IIB             Blood                     NaN  ...            93.33
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# ...

# %%
#Micov - genome level for taxonomy barplots
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_none_WOL_scrubbed_micov', micov_filter='Fitz_all', rare_level=150000)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            93.72
# 1  IIIC  Normal esophagus                     3.0  ...            93.70
# 2   IIB             Blood                     NaN  ...            93.33
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# ...

# %%
#Micov - Male Only
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_species_WOL_scrubbed_micov_MO', micov_filter='Fitz_all', rare_level=150000, sex_split=['M'])
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_11_EGAF00000586547      11         EAC
# 1  Tumor_12_EGAF00000525525      12         EAC
# 2  Tumor_14_EGAF00000560172      14         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 1  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
# 2        St Thomas Hospital, London      M                        68  T3N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0  IIIC  Normal esophagus                     3.0  ...            93.70
# 1   IIB             Blood                     NaN  ...            93.33
# 2  IIIA             Blood                     6.0  ...            93.87
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              306.0      5.03           0.224                   58.86
# ...

# %%
#Micov - Female Only
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_species_WOL_scrubbed_micov_FO', micov_filter='Fitz_all', rare_level=150000, sex_split=['F'])
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_13_EGAF00000525466      13         EAC
# 2  Tumor_20_EGAF00000560131      20         EAC
#
#                                     Centre Gender  Age_at_time_of_diagnosis  \
# 0         Addenbrookes Hospital, Cambridge      F                        79
# 1  Royal Surrey County Hospital, Guildford      F                        61
# 2     Edinburgh Royal Infirmary, Edinburgh      F                        79
#
#      TNM7 Stage Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0  T2N0M0    IB           Blood                     4.0  ...            93.72
# 1  T2N0M0    IB           Blood                    15.0  ...            93.49
# 2  T3N1M0  IIIA           Blood                     NaN  ...            94.00
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# ...

# %% [markdown]
# ### [Supplemental] From Sam: Barrett's Esophgous Progressors/Non Progressors: using MetaPhlan4
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# Note:
# Classic MetaPhlan4 : /Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv (remove the 'True' if you want this)
# Counts MetaPhlan4: /Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
Sam_BE_data_split(['NP'], ['T1'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_NP_T1_species_MP_counts', True, rare_level=300)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
# Total number of samples in BE_NP_T1_species_MP_counts-paper10-28-24  =  53
# ...

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T2

# %%
Sam_BE_data_split(['NP'], ['T2'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_NP_T2_species_MP_counts', True, rare_level=300)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
# Total number of samples in BE_NP_T2_species_MP_counts-paper10-28-24  =  58
# ...

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
Sam_BE_data_split(['Prog'], ['T1'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_Prog_T1_species_MP_counts', True, rare_level=300)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
# Total number of samples in BE_Prog_T1_species_MP_counts-paper10-28-24  =  40
# <artifact: FeatureTable[Frequency] uuid: bd195c31-98cb-4a20-978c-241f2c96bd68>
# DF len 189

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %%
Sam_BE_data_split(['Prog'], ['T2'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_Prog_T2_species_MP_counts', True, rare_level=300)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
# Total number of samples in BE_Prog_T2_species_MP_counts-paper10-28-24  =  51
# <artifact: FeatureTable[Frequency] uuid: 253b4c8b-f361-42dc-b02d-42ff9451d724>
# DF len 189
