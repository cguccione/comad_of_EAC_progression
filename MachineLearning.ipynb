# %% [markdown]
# # Runs Machine Learning Models: BE Progresson levels and Normal vs. BE vs. EAC
# Creates random forest ML models in order to see if there a differences in microbies across various groups

# %% [markdown]
# ### Imports

# %%
##NOTE: NEED TO FIX CONDA ENV: rn working with selection**

import os

# %matplotlib inline
import matplotlib

from python_scripts.machine_learning import *
# Out:
# /Users/cguccion/miniconda3/envs/selection/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Datatypes

# %% [markdown]
# ### Barrett's Esophgous Progressors/Non Progressors
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# #### Using Genome RS210, all microbes

# %%
ML('BE_genome_RS210', 'progressionstatus', 5)
# Out:
# {'NP', 'Prog'}
# Stratfied-split
# Cross validation testing size = 42.279999999999994
# Cross Validation
# Cross validation testing size = 60.4

# %%
ML('BE_NP_genome_RS210', 'sampletype_progressionstatus', 5)
# Out:
# {'T2_NP', 'T1_NP'}
# Stratfied-split
# Cross validation testing size = 21.0
# Cross Validation
# Cross validation testing size = 30.0

# %%
ML('BE_Prog_genome_RS210', 'sampletype_progressionstatus', 5)
# Out:
# {'T2_Prog', 'T1_Prog'}
# Stratfied-split
# Cross validation testing size = 21.279999999999998
# Cross Validation
# Cross validation testing size = 30.4

# %%
ML('BE_T1_genome_RS210', 'progressionstatus', 5)
# Out:
# {'Prog', 'NP'}
# Stratfied-split
# Cross validation testing size = 21.279999999999998
# Cross Validation
# Cross validation testing size = 30.4

# %%
ML('BE_T2_genome_RS210', 'progressionstatus', 5)
# Out:
# {'Prog', 'NP'}
# Stratfied-split
# Cross validation testing size = 21.0
# Cross Validation
# Cross validation testing size = 30.0

# %% [markdown]
# #### Using Species WOL, Top Non-Neutarl Microbes in BE Species WOL

# %%
ML('BE_species_WOL', 'progressionstatus', 5, 'BE_species_WOL')
# Out:
# Using only top 64 non-neutral microbes from BE_species_WOL
# {'NP', 'Prog'}
# Stratfied-split
# Cross validation testing size = 44.239999999999995
# Cross Validation
# Cross validation testing size = 63.2

# %%
ML('BE_T1_species_WOL', 'progressionstatus', 5, 'BE_species_WOL')
# Out:
# Using only top 64 non-neutral microbes from BE_species_WOL
# {'NP', 'Prog'}
# Stratfied-split
# Cross validation testing size = 22.259999999999998
# Cross Validation
# Cross validation testing size = 31.8

# %%
ML('BE_T2_species_WOL', 'progressionstatus', 5, 'BE_species_WOL')
# Out:
# Using only top 64 non-neutral microbes from BE_species_WOL
# {'NP', 'Prog'}
# Stratfied-split
# Cross validation testing size = 21.979999999999997
# Cross Validation
# Cross validation testing size = 31.4

# %% [markdown]
# #### Normal, BE, EAC Tissue
# Ross-Innes, C. S. et al. Whole-genome sequencing provides new insights into the clonal architecture of Barrett’s esophagus and esophageal adenocarcinoma. Nature Genetics vol. 47 1038–1046 (2015) https://doi.org/10.1038/ng.3357

# %%
ML('ALL_Ross_paired_species_WOL', 'Sample_type', 5)
# Out:
# {'EAC', 'Normal', 'Barretts'}
# Stratfied-split
# Cross validation testing size = 12.319999999999999
# Cross Validation
# Cross validation testing size = 17.6

# %%
ML('BE_EAC_Ross_paired_species_WOL', 'Sample_type', 4)
# Out:
# {'EAC', 'Barretts'}
# Stratfied-split
# Cross validation testing size = 11.375
# Cross Validation
# Cross validation testing size = 16.25

# %%
ML('Norm_BE_Ross_paired_species_WOL', 'Sample_type', 4)
# Out:
# {'Normal', 'Barretts'}
# Stratfied-split
# Cross validation testing size = 10.149999999999999
# Cross Validation
# Cross validation testing size = 14.5
