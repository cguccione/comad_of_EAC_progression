# %% [markdown]
# # Genearate Data
# Generate all data needed to run analysis

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import qiime2 as q2
from qiime2.plugins import taxa

from python_scripts.import_split_biom import *

# %% [markdown]
# ### Datatypes

# %% [markdown]
# ### EAC ICGC
#
# "Pan-Cancer Analysis of Whole Genomes." Nature, vol. 578, no. 7793, 2020, pp. 82-93,  https://doi.org/10.1038/s41586-020-1969-6. Accessed 17 Jan. 2024.
#
# (Qiita: 14857)

# %% [markdown]
# ###### Used in paper

# %%
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_ginnyR_species_WOL_scrubbed', Ginny_list=True)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# 2              alive  ...                     NaN                    PCAWG
# 3              alive  ...                    74.0                    PCAWG
#
#   donor_age_at_last_followup  disease_status_last_followup  \
# 1                       66.0        no evidence of disease
# 2                       68.0                        stable
# 3                       76.0        no evidence of disease
#
#    donor_interval_of_last_followup  donor_tumour_stage_at_diagnosis  \
# 1                            712.0                           T2N0M0
# 2                            401.0                           T3N1M0
# 3                            767.0                           T2N0M0
#
#   cancer_history_first_degree_relative  \
# 1                                   no
# 2                              unknown
# 3                                   no
#
#    donor_tumour_staging_system_at_diagnosis  \
# 1                                      TNM7
# 2                                      TNM6
# 3                                      TNM7
#
#   donor_tumour_stage_at_diagnosis_supplemental  qiita_study_id
# 1                                      UICC:1b           14857
# 2                                       UICC:3           14857
# 3                                      UICC:1b           14857
#
# [3 rows x 25 columns]
# Total number of samples in EAC_ICGC_ginnyR_species_WOL_scrubbed  =  83
# <artifact: FeatureTable[Frequency] uuid: f93e08ee-a9f5-488c-8afd-d0d8a32ab2b9>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:133: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_ginnyR_species_WOL_scrubbed_rmBad', Ginny_list=True, remove_bad_microbes=True)
# Out:
#                                     sample_name  project  \
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
# 3  14857.14521.04ceb5f141916f7fc091a5e0aa51ada3  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
# 3  04ceb5f141916f7fc091a5e0aa51ada3.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy donor_relapse_type  \
# 1       DO50389       SA528947          unknown                NaN
# 2       DO50412       SA528884          unknown                NaN
# 3       DO50406       SA528949          unknown                NaN
#
#   donor_vital_status  ... donor_age_at_enrollment  study_donor_involved_in  \
# 1           deceased  ...                    65.0                    PCAWG
# 2              alive  ...                     NaN                    PCAWG
# 3              alive  ...                    74.0                    PCAWG
#
#   donor_age_at_last_followup  disease_status_last_followup  \
# 1                       66.0        no evidence of disease
# 2                       68.0                        stable
# 3                       76.0        no evidence of disease
#
#    donor_interval_of_last_followup  donor_tumour_stage_at_diagnosis  \
# 1                            712.0                           T2N0M0
# 2                            401.0                           T3N1M0
# 3                            767.0                           T2N0M0
#
#   cancer_history_first_degree_relative  \
# 1                                   no
# 2                              unknown
# 3                                   no
#
#    donor_tumour_staging_system_at_diagnosis  \
# 1                                      TNM7
# 2                                      TNM6
# 3                                      TNM7
#
#   donor_tumour_stage_at_diagnosis_supplemental  qiita_study_id
# 1                                      UICC:1b           14857
# 2                                       UICC:3           14857
# 3                                      UICC:1b           14857
#
# [3 rows x 25 columns]
# Total number of samples in EAC_ICGC_ginnyR_species_WOL_scrubbed_rmBad  =  83
# <artifact: FeatureTable[Frequency] uuid: 3d723418-2280-4477-971f-eb9aa9034a25>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:133: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
#NOTE: This was used prior to May 2024 -- but a little tricky in how things were removed so going to clean it up now
#since we have to re-do with exact microbes from Ginny
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_wo-RI_species_WOL_scrubbed_rmBad',
                     remove_bad_microbes=True)
# Out:
#                                     sample_name  project  \
# 0  14857.14521.006cdcd42d55e07a2fd1ad2d31dd1a87  ESAD-UK
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam      male      ESAD-UK
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy  \
# 0       DO50381       SA528854          unknown
# 1       DO50389       SA528947          unknown
# 2       DO50412       SA528884          unknown
#
#               donor_relapse_type donor_vital_status  ...  \
# 0  distant recurrence/metastasis           deceased  ...
# 1                            NaN           deceased  ...
# 2                            NaN              alive  ...
#
#   donor_age_at_enrollment  study_donor_involved_in donor_age_at_last_followup  \
# 0                    58.0                    PCAWG                       58.0
# 1                    65.0                    PCAWG                       66.0
# 2                     NaN                    PCAWG                       68.0
#
#    disease_status_last_followup  donor_interval_of_last_followup  \
# 0                       relapse                            299.0
# 1        no evidence of disease                            712.0
# 2                        stable                            401.0
#
#    donor_tumour_stage_at_diagnosis cancer_history_first_degree_relative  \
# 0                           T3N1M0                              unknown
# 1                           T2N0M0                                   no
# 2                           T3N1M0                              unknown
#
#    donor_tumour_staging_system_at_diagnosis  \
# 0                                      TNM7
# 1                                      TNM7
# 2                                      TNM6
#
#   donor_tumour_stage_at_diagnosis_supplemental  qiita_study_id
# 0                                      UICC:3a           14857
# 1                                      UICC:1b           14857
# 2                                       UICC:3           14857
#
# [3 rows x 25 columns]
# Total number of samples in EAC_ICGC_wo-RI_species_WOL_scrubbed_rmBad  =  97
# <artifact: FeatureTable[Frequency] uuid: c5d588cb-fe0d-49b7-b529-3f7484f23196>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not in paper

# %%
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_wo-RI_species_WOL_scrubbed')

# %%
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_species_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_species_WOL_scrubbed')
# Out:
#                                     sample_name  project  \
# 0  14857.14521.006cdcd42d55e07a2fd1ad2d31dd1a87  ESAD-UK
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam      male      ESAD-UK
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy  \
# 0       DO50381       SA528854          unknown
# 1       DO50389       SA528947          unknown
# 2       DO50412       SA528884          unknown
#
#               donor_relapse_type donor_vital_status  ...  \
# 0  distant recurrence/metastasis           deceased  ...
# 1                            NaN           deceased  ...
# 2                            NaN              alive  ...
#
#   donor_age_at_enrollment  study_donor_involved_in donor_age_at_last_followup  \
# 0                    58.0                    PCAWG                       58.0
# 1                    65.0                    PCAWG                       66.0
# 2                     NaN                    PCAWG                       68.0
#
#    disease_status_last_followup  donor_interval_of_last_followup  \
# 0                       relapse                            299.0
# 1        no evidence of disease                            712.0
# 2                        stable                            401.0
#
#    donor_tumour_stage_at_diagnosis cancer_history_first_degree_relative  \
# 0                           T3N1M0                              unknown
# 1                           T2N0M0                                   no
# 2                           T3N1M0                              unknown
#
#    donor_tumour_staging_system_at_diagnosis  \
# 0                                      TNM7
# 1                                      TNM7
# 2                                      TNM6
#
#   donor_tumour_stage_at_diagnosis_supplemental  qiita_study_id
# 0                                      UICC:3a           14857
# 1                                      UICC:1b           14857
# 2                                       UICC:3           14857
#
# [3 rows x 25 columns]
# Total number of samples in EAC_ICGC_species_WOL_scrubbed  =  97
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_none_WoLr1_scrubbed/feature-table.biom',
                'EAC_ICGC_genome_WOL_scrubbed')
# Out:
#                                     sample_name  project  \
# 0  14857.14521.006cdcd42d55e07a2fd1ad2d31dd1a87  ESAD-UK
# 1  14857.14521.0337efea9b59b88f804ea384c356377c  ESAD-UK
# 2  14857.14521.04a446c6a660694dafe43ccaf1db7162  ESAD-UK
#
#                                         filename donor_sex project_code  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam      male      ESAD-UK
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam      male      ESAD-UK
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam      male      ESAD-UK
#
#   icgc_donor_id icgc_sample_id prior_malignancy  \
# 0       DO50381       SA528854          unknown
# 1       DO50389       SA528947          unknown
# 2       DO50412       SA528884          unknown
#
#               donor_relapse_type donor_vital_status  ...  \
# 0  distant recurrence/metastasis           deceased  ...
# 1                            NaN           deceased  ...
# 2                            NaN              alive  ...
#
#   donor_age_at_enrollment  study_donor_involved_in donor_age_at_last_followup  \
# 0                    58.0                    PCAWG                       58.0
# 1                    65.0                    PCAWG                       66.0
# 2                     NaN                    PCAWG                       68.0
#
#    disease_status_last_followup  donor_interval_of_last_followup  \
# 0                       relapse                            299.0
# 1        no evidence of disease                            712.0
# 2                        stable                            401.0
#
#    donor_tumour_stage_at_diagnosis cancer_history_first_degree_relative  \
# 0                           T3N1M0                              unknown
# 1                           T2N0M0                                   no
# 2                           T3N1M0                              unknown
#
#    donor_tumour_staging_system_at_diagnosis  \
# 0                                      TNM7
# 1                                      TNM7
# 2                                      TNM6
#
#   donor_tumour_stage_at_diagnosis_supplemental  qiita_study_id
# 0                                      UICC:3a           14857
# 1                                      UICC:1b           14857
# 2                                       UICC:3           14857
#
# [3 rows x 25 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 eac_14857_data_split(os.getcwd() +'/qiita_downloads/qiita14857_EAC_ICGC/162938_none_WoLr1_scrubbed/feature-table.biom',
#       2                 'EAC_ICGC_genome_WOL_scrubbed')
#
# File ~/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:233, in eac_14857_data_split(biom, fn, trim)
#     230 display(meta[:3])
#     232 #Create all files based on biom/meta_custom
# --> 233 data_split_helper(biom, meta, fn, zebra=zebra)
#     235 return()
#
# NameError: name 'zebra' is not defined

# %% [markdown]
# ### Normal/Healthy & GERD Esoph Brushings
# Deshpande, N. P., Riordan, S. M., Castaño-Rodríguez, N., Wilkins, M. R. & Kaakoush, N. O. Signatures within the esophageal microbiome are associated with host genetics, age, and disease. Microbiome vol. 6 (2018) https://doi.org/10.1186/s40168-018-0611-4

# %% [markdown]
# ##### Convert to various types form Qiime2 (only had to run once)

# %%
#Table
table = q2.Artifact.import_data('FeatureTable[Frequency]', os.getcwd() + '/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom')

#WOL Taxonomy
taxdf = pd.read_csv('/Users/cguccion/Dropbox/Storage/HelpfulLabDocs/taxonomy_trees/WOL/lineages.txt', sep='\t', index_col=0, header=None)
taxdf.columns = ['Taxon']
taxdf.index.name = 'Feature ID'
taxonomy = q2.Artifact.import_data('FeatureData[Taxonomy]', taxdf)

collapsed_table = taxa.methods.collapse(table=table, taxonomy=taxonomy, level=7).collapsed_table

#display(collapsed_table.view(pd.DataFrame).T)
Artifact.export_data(collapsed_table, 'species_WOL')

# %% [markdown]
# ##### Normal / Healthy Esophgous

# %% [markdown]
# ###### Used in paper

# %%
#Wol Scrubbed
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'normal_species_WOL_scrubbed')
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL_scrubbed  =  50
# <artifact: FeatureTable[Frequency] uuid: f3ca9e18-c070-49fc-a3a3-6510ffc68ec7>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not in paper

# %%
#Wol Scrubbed
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'normal_genome_WOL_scrubbed')

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'normal_zebra_genome_WOL_scrubbed',
                      zebra='norm_GERD_WOL')

#
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169129_perGenome_RS210.biom',
                       'normal_genome_RS210')

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/species_WOL/feature-table.biom',
                       'normal_species_WOL')

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'normal_genome_WOL')

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'normal_zebra_genome_WOL',
                       zebra='norm_GERD_WOL')

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'normal_23_genome_WOL',
                      trim =23)

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/species_WOL/feature-table.biom',
                       'normal_23_species_WOL',
                      trim = 23)

gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'normal_zebra_23_genome_WOL',
                       zebra='norm_GERD_WOL',
                      trim = 23)
# Out:
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_genome_WOL_scrubbed  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_zebra_genome_WOL_scrubbed  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_genome_RS210  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_species_WOL  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_genome_WOL  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 1  14458.ERR2373134   70  YES      F     YES    Normal     H96_S87_SG
# 2  14458.ERR2373133   23  YES      F     YES    Normal     H95_S86_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0              NO                H98           14458
# 1              NO                H96           14458
# 2              NO                H95           14458
# Total number of samples in normal_zebra_genome_WOL  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#          sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 45  14458.ERR2373058   49  NO      F     YES    Normal     H12_S11_SG
# 30  14458.ERR2373089   34  NO      F     YES    Normal     H48_S42_SG
# 3   14458.ERR2373127   49  NO      M     YES    Normal     H90_S80_SG
#
#    reflux_symptoms metadata_sample_id  qiita_study_id
# 45              NO                H12           14458
# 30              NO                H48           14458
# 3               NO                H90           14458
# Total number of samples in normal_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#          sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 18  14458.ERR2373106   60  YES      F     YES    Normal     H66_S59_SG
# 12  14458.ERR2373117   51  YES      F     YES    Normal     H79_S70_SG
# 32  14458.ERR2373083   31   NO      F     YES    Normal     H41_S36_SG
#
#    reflux_symptoms metadata_sample_id  qiita_study_id
# 18              NO                H66           14458
# 12              NO                H79           14458
# 32              NO                H41           14458
# Total number of samples in normal_23_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#          sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 0   14458.ERR2373136   55  YES      F     YES    Normal     H98_S89_SG
# 24  14458.ERR2373095   57  YES      M     YES    Normal     H55_S48_SG
# 39  14458.ERR2373075   82  YES      M     YES    Normal     H29_S28_SG
#
#    reflux_symptoms metadata_sample_id  qiita_study_id
# 0               NO                H98           14458
# 24              NO                H55           14458
# 39              NO                H29           14458
# Total number of samples in normal_zebra_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### GERD

# %% [markdown]
# ###### Used in paper

# %%
#Wol scrubbed

gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_species_WOL_scrubbed/feature-table.biom',
                       'GERD_species_WOL_scrubbed')
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_species_WOL_scrubbed  =  29
# <artifact: FeatureTable[Frequency] uuid: 023fbb04-764c-45af-85ad-fb081504e2d9>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not in paper

# %%
#Wol Scrubbed
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'GERD_genome_WOL_scrubbed')

gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL_scrubbed/feature-table.biom',
                       'GERD_zebra_genome_WOL_scrubbed',
                       zebra='norm_GERD_WOL')
                       
#
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/169129_perGenome_RS210.biom',
                       'GERD_genome_RS210')

gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/species_WOL/feature-table.biom',
                       'GERD_species_WOL')

gerd_normal_data_split('GERD',
                       os.getcwd() + '/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'GERD_genome_WOL')

gerd_normal_data_split('GERD',
                       os.getcwd() + '/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'GERD_zebra_genome_WOL',
                       zebra='norm_GERD_WOL')

gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14458_NormalGerdEsoph/species_WOL/feature-table.biom',
                       'GERD_23_species_WOL',
                      trim =23)

gerd_normal_data_split('GERD',
                       os.getcwd() + '/qiita_downloads/qiita14458_NormalGerdEsoph/169125_none_WOL.biom',
                       'GERD_zebra_23_genome_WOL',
                       zebra='norm_GERD_WOL',
                      trim = 23)
# Out:
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_genome_WOL_scrubbed  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_zebra_genome_WOL_scrubbed  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_genome_RS210  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_species_WOL  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_genome_WOL  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#         sample_name  age ppi gender shotgun diagnosis og_sample_name  \
# 0  14458.ERR2373137   53  NO      M     YES      GERD     H99_S90_SG
# 1  14458.ERR2373135   36  NO      M     YES      GERD     H97_S88_SG
# 2  14458.ERR2373132   34  NO      F     YES      GERD     H94_S85_SG
#
#   reflux_symptoms metadata_sample_id  qiita_study_id
# 0             YES                H99           14458
# 1             YES                H97           14458
# 2             YES                H94           14458
# Total number of samples in GERD_zebra_genome_WOL  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#          sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 25  14458.ERR2373059   67   NO      F     YES      GERD     H13_S12_SG
# 4   14458.ERR2373130   42  YES      F     YES      GERD     H92_S83_SG
# 26  14458.ERR2373057   39   NO      F     YES      GERD     H11_S10_SG
#
#    reflux_symptoms metadata_sample_id  qiita_study_id
# 25              NO                H13           14458
# 4              YES                H92           14458
# 26             YES                H11           14458
# Total number of samples in GERD_23_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#          sample_name  age  ppi gender shotgun diagnosis og_sample_name  \
# 13  14458.ERR2373102   44   NO      F     YES      GERD     H62_S55_SG
# 1   14458.ERR2373135   36   NO      M     YES      GERD     H97_S88_SG
# 4   14458.ERR2373130   42  YES      F     YES      GERD     H92_S83_SG
#
#    reflux_symptoms metadata_sample_id  qiita_study_id
# 13             YES                H62           14458
# 1              YES                H97           14458
# 4              YES                H92           14458
# Total number of samples in GERD_zebra_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# #### (not in paper) 16S DATA!!! (More info in Kit testing folder of comad ... done on 10/24/23)

# %% [markdown]
# ##### Normal - 16S

# %%
gerd_normal_data_split('Normal',
                       os.getcwd() +'/qiita_downloads/qiita14325_16S_NormalGerdEsoph/139540_reference-hit_prep12316.biom',
                       'normal_16S',
                      shotgun=False)
# Out:
#   sample_name   age  ppi gender shotgun diagnosis reflux_symptoms  \
# 0    14325.H3  53.0  YES      F     YES    Normal              NO
# 1    14325.H5  58.0   NO      F     YES    Normal              NO
# 2    14325.H6  56.0  YES      F     YES    Normal              NO
#
#    qiita_study_id metadata_sample_id
# 0           14325                 H3
# 1           14325                 H5
# 2           14325                 H6
# Total number of samples in normal_16S  =  50
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### GERD - 16S

# %%
gerd_normal_data_split('GERD',
                       os.getcwd() +'/qiita_downloads/qiita14325_16S_NormalGerdEsoph/139540_reference-hit_prep12316.biom',
                       'GERD_16S',
                      shotgun=False)
# Out:
#   sample_name   age  ppi gender shotgun diagnosis reflux_symptoms  \
# 0    14325.H2  62.0   NO      F     YES      GERD             YES
# 1    14325.H4  76.0  YES      M     YES      GERD             YES
# 2    14325.H7  76.0   NO      M     YES      GERD             YES
#
#    qiita_study_id metadata_sample_id
# 0           14325                 H2
# 1           14325                 H4
# 2           14325                 H7
# Total number of samples in GERD_16S  =  29
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ### Barrett's Esophgous Progressors/Non Progressors
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# ##### (Not in paper) Barrett's Esophgous

# %%
be_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_genome_RS210')

be_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_species_WOL')

be_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_genome_WOL')

be_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_zebra_genome_WOL',
             zebra = 'BE_WOL')

be_data_split(['NP', 'Prog'], ['T1', 'T2','LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'all_BE_genome_WOL')
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_genome_RS210  =  302
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_species_WOL  =  316
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_genome_WOL  =  316
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_zebra_genome_WOL  =  316
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in all_BE_genome_WOL  =  336
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors

# %% [markdown]
# ###### Used in paper

# %%
#WOL scrubbed -TP1

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed')
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_species_WOL_scrubbed  =  80
# <artifact: FeatureTable[Frequency] uuid: 3139877c-5e5a-463c-a9cd-f0cbf2655e2c>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
#WOL scrubbed

be_data_split(['NP'], ['T1', 'T2', 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_wLF_species_WOL_scrubbed')
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_wLF_species_WOL_scrubbed  =  178
# <artifact: FeatureTable[Frequency] uuid: 5e01b2b6-6a62-4ebd-902b-7b084a091965>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Used in supp ?

# %%
be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_species_WOL_scrubbed')

# %% [markdown]
# ###### Not in paper

# %%
#WOL scrubbed
be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_genome_WOL_scrubbed')

be_data_split(['NP'], ['T1', 'T2', 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_wLF_zebra_genome_WOL_scrubbed',
             zebra = 'BE_WOL')

be_data_split(['NP'], ['T1', 'T2', 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_wLF_genome_WOL_scrubbed')

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_genome_WOL_scrubbed')

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_zebra_genome_WOL_scrubbed',
             zebra = 'BE_WOL')

be_data_split(['NP'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_NP_T2_genome_WOL_scrubbed')

#
be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_NP_genome_RS210')

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_species_WOL')

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_zebra_genome_WOL',
             zebra = 'BE_WOL')

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_exact_genome_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_exact_species_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_zebra_exact_genome_WOL',
             zebra = 'BE_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_zebra_23_genome_WOL',
             zebra = 'BE_WOL',
             trim = 23)
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_genome_WOL_scrubbed  =  158
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_wLF_zebra_genome_WOL_scrubbed  =  178
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_wLF_genome_WOL_scrubbed  =  178
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_genome_WOL_scrubbed  =  80
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_zebra_genome_WOL_scrubbed  =  80
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_genome_WOL_scrubbed  =  78
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_genome_RS210  =  150
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_species_WOL  =  158
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T2_NP
# Total number of samples in BE_NP_zebra_genome_WOL  =  158
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M        17         T1
# 1  14598.PCGA.1064.BE.03      White_nonHispanic      M        17         T2
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M        55         T1
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               3            23561
# 1           1  17-24987N-105W-BLD               4            23567
# 2           1  55-25056N-204U-BLD               3            23611
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              78.83          14598
# 1                NP              87.07          14598
# 2                NP              53.23          14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T2_NP
# 2                        T1_NP
# Total number of samples in BE_NP_exact_genome_WOL  =  80
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M        17         T1
# 1  14598.PCGA.1064.BE.03      White_nonHispanic      M        17         T2
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M        55         T1
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               3            23561
# 1           1  17-24987N-105W-BLD               4            23567
# 2           1  55-25056N-204U-BLD               3            23611
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              78.83          14598
# 1                NP              87.07          14598
# 2                NP              53.23          14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T2_NP
# 2                        T1_NP
# Total number of samples in BE_NP_exact_species_WOL  =  80
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M        17         T1
# 1  14598.PCGA.1064.BE.03      White_nonHispanic      M        17         T2
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M        55         T1
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               3            23561
# 1           1  17-24987N-105W-BLD               4            23567
# 2           1  55-25056N-204U-BLD               3            23611
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              78.83          14598
# 1                NP              87.07          14598
# 2                NP              53.23          14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T2_NP
# 2                        T1_NP
# Total number of samples in BE_NP_zebra_exact_genome_WOL  =  80
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                sample_name                          race gender  patientid  \
# 50   14598.PCGA.1087.BE.04             White_nonHispanic      M        385
# 112  14598.PCGA.1123.BE.03  AmericanIndian_AlaskanNative      M        806
# 55   14598.PCGA.1095.BE.01             White_nonHispanic      M        478
#
#     sampletype  ismainstudy         pairednormal  distancefromgej  \
# 50          T2            1  385-24955N-148R-GST                2
# 112         T2            1   806-25035N-53S-BLD                2
# 55          T1            1  478-25071N-116V-BLD                2
#
#      orginal_sampleid progressionstatus  patientageatsample  qiita_study_id  \
# 50              24819                NP               68.34           14598
# 112             24157                NP               60.13           14598
# 55              23938                NP               71.24           14598
#
#     sampletype_progressionstatus
# 50                         T2_NP
# 112                        T2_NP
# 55                         T1_NP
# Total number of samples in BE_NP_zebra_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Supp ?) Barrett's Esophgous Non Progressors T1

# %%
#Used in supp.

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T1_species_WOL_scrubbed')
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_species_WOL_scrubbed  =  80
# <artifact: FeatureTable[Frequency] uuid: 2dd1c7db-8044-4682-8954-5db78d0cf5f9>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_NP_T1_genome_RS210')

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_T1_species_WOL')

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_T1_exact_species_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T1'], 
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_T1_exact_zebra_genome_WOL',
             zebra = 'BE_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_T1_exact_23_species_WOL',
             exact_pairs = True,
              trim = 23)

be_data_split(['NP'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_T1_exact_zebra_23_genome_WOL',
             exact_pairs = True,
              zebra = 'BE_WOL',
              trim = 23)

be_data_split(['NP'], ['T1'], 
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_T1_zebra_genome_WOL',
             zebra = 'BE_WOL')
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_genome_RS210  =  76
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_species_WOL  =  80
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M        17         T1
# 1  14598.PCGA.1067.BE.01  Asian_PacificIslander      M        55         T1
# 2  14598.PCGA.1068.BE.01      White_nonHispanic      M        59         T1
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               3            23561
# 1           1  55-25056N-204U-BLD               3            23611
# 2           1  59-24989N-165S-BLD               3            23638
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              78.83          14598
# 1                NP              53.23          14598
# 2                NP              67.14          14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_exact_species_WOL  =  40
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M        17         T1
# 1  14598.PCGA.1067.BE.01  Asian_PacificIslander      M        55         T1
# 2  14598.PCGA.1068.BE.01      White_nonHispanic      M        59         T1
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               3            23561
# 1           1  55-25056N-204U-BLD               3            23611
# 2           1  59-24989N-165S-BLD               3            23638
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              78.83          14598
# 1                NP              53.23          14598
# 2                NP              67.14          14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_exact_zebra_genome_WOL  =  40
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#               sample_name               race gender patientid sampletype  \
# 8   14598.PCGA.1078.BE.03  White_nonHispanic      M       222         T1
# 15  14598.PCGA.1096.BE.01  White_nonHispanic      M       483         T1
# 16  14598.PCGA.1098.BE.01  White_nonHispanic      M       515         T1
#
#    ismainstudy         pairednormal distancefromgej orginal_sampleid  \
# 8            1  222-25062N-179T-BLD               9            24376
# 15           1  483-24961N-246S-GST               6            23824
# 16           1   515-25073N-18V-BLD               3            23683
#
#    progressionstatus patientageatsample qiita_study_id  \
# 8                 NP              75.01          14598
# 15                NP              68.52          14598
# 16                NP              50.28          14598
#
#    sampletype_progressionstatus
# 8                         T1_NP
# 15                        T1_NP
# 16                        T1_NP
# Total number of samples in BE_NP_T1_exact_23_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#               sample_name               race gender patientid sampletype  \
# 27  14598.PCGA.1119.BE.01  White_nonHispanic      M       729         T1
# 31  14598.PCGA.1130.BE.01  White_nonHispanic      M       900         T1
# 24  14598.PCGA.1111.BE.01  White_nonHispanic      M       635         T1
#
#    ismainstudy         pairednormal distancefromgej orginal_sampleid  \
# 27           1  729-25033N-237R-BLD               1            23752
# 31           1   900-25089N-32P-GST               5            23926
# 24           1   635-25080N-95V-BLD               6            24037
#
#    progressionstatus patientageatsample qiita_study_id  \
# 27                NP              65.51          14598
# 31                NP              46.33          14598
# 24                NP              54.82          14598
#
#    sampletype_progressionstatus
# 27                        T1_NP
# 31                        T1_NP
# 24                        T1_NP
# Total number of samples in BE_NP_T1_exact_zebra_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                        T1_NP
# Total number of samples in BE_NP_T1_zebra_genome_WOL  =  80
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Supp ?) Barrett's Esophgous Non Progressors T2

# %%
#Used in supp.

be_data_split(['NP'], ['T2', 'LongFollowUp'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_NP_T2_wLT_species_WOL_scrubbed')
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_wLT_species_WOL_scrubbed  =  98
# <artifact: FeatureTable[Frequency] uuid: 8c4cabab-1aad-457f-b22b-55adbde8a71d>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
be_data_split(['NP'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_NP_T2_genome_RS210')

be_data_split(['NP'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_NP_T2_species_WOL')

be_data_split(['NP'], ['T2'], 
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_T2_exact_zebra_genome_WOL',
             zebra = 'BE_WOL',
             exact_pairs = True)

be_data_split(['NP'], ['T2'], 
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_NP_T2_zebra_genome_WOL',
             zebra = 'BE_WOL')
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_genome_RS210  =  74
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_species_WOL  =  78
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M        17         T2
# 1  14598.PCGA.1067.BE.02  Asian_PacificIslander      M        55         T2
# 2  14598.PCGA.1068.BE.03      White_nonHispanic      M        59         T2
#
#   ismainstudy        pairednormal distancefromgej orginal_sampleid  \
# 0           1  17-24987N-105W-BLD               4            23567
# 1           1  55-25056N-204U-BLD               1            23614
# 2           1  59-24989N-165S-BLD               3            23644
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0                NP              87.07          14598
# 1                NP              57.07          14598
# 2                NP               69.0          14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_exact_zebra_genome_WOL  =  40
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                        T2_NP
# Total number of samples in BE_NP_T2_zebra_genome_WOL  =  78
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) Barrett's Esophgous Progressors

# %%
be_data_split(['Prog'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_Prog_genome_RS210')

be_data_split(['Prog'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_Prog_species_WOL')

be_data_split(['Prog'], ['T1', 'T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_Prog_zebra_genome_WOL',
             zebra = 'BE_WOL')
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_genome_RS210  =  152
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_species_WOL  =  158
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_zebra_genome_WOL  =  158
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %% [markdown]
# ###### Used in paper

# %%
#WOL scrubbed

be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_species_WOL_scrubbed')
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_T1_species_WOL_scrubbed  =  79
# <artifact: FeatureTable[Frequency] uuid: 9c594e17-9ee5-4aea-b753-b8d5c3a5ceb9>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not used in paper

# %%
#WOL scrubbed
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_genome_WOL_scrubbed')

be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T1_zebra_genome_WOL_scrubbed',
              zebra = 'BE_WOL')

#
be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_Prog_T1_genome_RS210')

be_data_split(['Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_Prog_T1_species_WOL')
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_T1_genome_WOL_scrubbed  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_T1_zebra_genome_WOL_scrubbed  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_T1_genome_RS210  =  76
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
#
#   sampletype_progressionstatus
# 0                      T1_Prog
# 1                      T1_Prog
# 2                      T1_Prog
# Total number of samples in BE_Prog_T1_species_WOL  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %% [markdown]
# ###### Used in paper

# %%
#WOL scrubbed

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T2_species_WOL_scrubbed')
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_species_WOL_scrubbed  =  79
# <artifact: FeatureTable[Frequency] uuid: a9ee04bc-9036-4143-8b21-30b9c5b6cb4d>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not used in paper

# %%
#WOL scrubbed
be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL_scrubbed/feature-table.biom',
              'BE_Prog_T2_genome_WOL_scrubbed')

#
be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_Prog_T2_genome_RS210')

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_Prog_T2_species_WOL')

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_Prog_T2_genome_WOL')

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_Prog_T2_exact_species_WOL',
             exact_pairs = True)

be_data_split(['Prog'], ['T2'], 
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_Prog_T2_exact_zebra_genome_WOL',
             zebra = 'BE_WOL',
             exact_pairs = True)

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_Prog_T2_exact_23_species_WOL',
             exact_pairs = True,
              trim = 23)

be_data_split(['Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_Prog_T2_exact_zebra_23_genome_WOL',
             exact_pairs = True,
              zebra = 'BE_WOL',
              trim = 23)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_genome_WOL_scrubbed  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_genome_RS210  =  76
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_species_WOL  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_genome_WOL  =  79
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender patientid sampletype  \
# 0  14598.PCGA.1065.BE.01      Other_Unknown      M        42         T2
# 1  14598.PCGA.1066.BE.02      Other_Unknown      F        43         T2
# 2  14598.PCGA.1069.BE.02  White_nonHispanic      M        74         T2
#
#   ismainstudy       pairednormal distancefromgej orginal_sampleid  \
# 0           1  42-24954N-53L-GST               5            24283
# 1           1  43-24956N-29P-GST               4            23593
# 2           1  74-25057N-80U-BLD               4            23677
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0              Prog              57.65          14598
# 1              Prog              65.07          14598
# 2              Prog              52.21          14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_exact_species_WOL  =  40
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender patientid sampletype  \
# 0  14598.PCGA.1065.BE.01      Other_Unknown      M        42         T2
# 1  14598.PCGA.1066.BE.02      Other_Unknown      F        43         T2
# 2  14598.PCGA.1069.BE.02  White_nonHispanic      M        74         T2
#
#   ismainstudy       pairednormal distancefromgej orginal_sampleid  \
# 0           1  42-24954N-53L-GST               5            24283
# 1           1  43-24956N-29P-GST               4            23593
# 2           1  74-25057N-80U-BLD               4            23677
#
#   progressionstatus patientageatsample qiita_study_id  \
# 0              Prog              57.65          14598
# 1              Prog              65.07          14598
# 2              Prog              52.21          14598
#
#   sampletype_progressionstatus
# 0                      T2_Prog
# 1                      T2_Prog
# 2                      T2_Prog
# Total number of samples in BE_Prog_T2_exact_zebra_genome_WOL  =  40
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#               sample_name               race gender patientid sampletype  \
# 11  14598.PCGA.1088.BE.03  White_nonHispanic      M       387         T2
# 31  14598.PCGA.1124.BE.02  White_nonHispanic      M       833         T2
# 14  14598.PCGA.1091.BE.01  White_nonHispanic      M       403         T2
#
#    ismainstudy         pairednormal distancefromgej orginal_sampleid  \
# 11           1  387-24974N-309J-GST               0            23662
# 31           1  833-25085N-211U-BLD               3            24016
# 14           1  403-24957N-153N-GST               6            24383
#
#    progressionstatus patientageatsample qiita_study_id  \
# 11              Prog              70.26          14598
# 31              Prog              80.53          14598
# 14              Prog              77.81          14598
#
#    sampletype_progressionstatus
# 11                      T2_Prog
# 31                      T2_Prog
# 14                      T2_Prog
# Total number of samples in BE_Prog_T2_exact_23_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#               sample_name               race gender patientid sampletype  \
# 16  14598.PCGA.1094.BE.02  White_nonHispanic      M       450         T2
# 36  14598.PCGA.1136.BE.03  White_nonHispanic      F       954         T2
# 9   14598.PCGA.1082.BE.03  White_nonHispanic      M       295         T2
#
#    ismainstudy         pairednormal distancefromgej orginal_sampleid  \
# 16           1  450-25070N-120R-BLD               1            23920
# 36           1  954-25048N-259T-BLD               2            24214
# 9            1   295-25066N-72T-BLD               1            24175
#
#    progressionstatus patientageatsample qiita_study_id  \
# 16              Prog              46.46          14598
# 36              Prog              77.46          14598
# 9               Prog              69.51          14598
#
#    sampletype_progressionstatus
# 16                      T2_Prog
# 36                      T2_Prog
# 9                       T2_Prog
# Total number of samples in BE_Prog_T2_exact_zebra_23_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Might be used in paper) Barrett's Esophgous T1

# %%
#Date: 5/23/2024; Goal: To create a TP1 NCO vs. TP1 CO to run birdman

be_data_split(['NP', 'Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_species_WOL_scrubbed/feature-table.biom',
              'BE_T1_species_WOL_scrubbed')
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1065.BE.03      Other_Unknown      M         42         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1   42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                      T1_Prog
# Total number of samples in BE_T1_species_WOL_scrubbed  =  159
# <artifact: FeatureTable[Frequency] uuid: 80f05428-f347-44b9-ac0b-b12b8ff66c23>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:133: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
be_data_split(['NP','Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_T1_genome_RS210')

be_data_split(['NP', 'Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_T1_species_WOL')

be_data_split(['NP', 'Prog'], ['T1'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_T1_genome_WOL')
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1065.BE.03      Other_Unknown      M         42         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1   42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                      T1_Prog
# Total number of samples in BE_T1_genome_RS210  =  152
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1065.BE.03      Other_Unknown      M         42         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1   42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                      T1_Prog
# Total number of samples in BE_T1_species_WOL  =  159
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1065.BE.03      Other_Unknown      M         42         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1   42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2              Prog               56.25           14598
#
#   sampletype_progressionstatus
# 0                        T1_NP
# 1                        T1_NP
# 2                      T1_Prog
# Total number of samples in BE_T1_genome_WOL  =  159
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) Barrett's Esophgous T2

# %%
be_data_split(['NP','Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/169098_perGenome_RS210.biom',
              'BE_T2_genome_RS210')

be_data_split(['NP', 'Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149428_species_WOL.biom',
              'BE_T2_species_WOL')

be_data_split(['NP', 'Prog'], ['T2'],
              os.getcwd() + '/qiita_downloads/qiita14598_BE_Esoph/149431_genome_WOL.biom',
              'BE_T2_genome_WOL')
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04  White_nonHispanic      M         17         T2
# 2  14598.PCGA.1065.BE.01      Other_Unknown      M         42         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1   42-24954N-53L-GST                5             24283
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2              Prog               57.65           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                      T2_Prog
# Total number of samples in BE_T2_genome_RS210  =  150
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04  White_nonHispanic      M         17         T2
# 2  14598.PCGA.1065.BE.01      Other_Unknown      M         42         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1   42-24954N-53L-GST                5             24283
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2              Prog               57.65           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                      T2_Prog
# Total number of samples in BE_T2_species_WOL  =  157
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04  White_nonHispanic      M         17         T2
# 2  14598.PCGA.1065.BE.01      Other_Unknown      M         42         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1   42-24954N-53L-GST                5             24283
#
#   progressionstatus  patientageatsample  qiita_study_id  \
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2              Prog               57.65           14598
#
#   sampletype_progressionstatus
# 0                        T2_NP
# 1                        T2_NP
# 2                      T2_Prog
# Total number of samples in BE_T2_genome_WOL  =  157
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ### Normal, BE, EAC Tissue
# Ross-Innes, C. S. et al. Whole-genome sequencing provides new insights into the clonal architecture of Barrett’s esophagus and esophageal adenocarcinoma. Nature Genetics vol. 47 1038–1046 (2015) https://doi.org/10.1038/ng.3357

# %% [markdown]
# ##### (Not used in paper) Normal, BE, EAC

# %%
normal_be_eac_data_split(['Normal', 'Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_combo_R1_R2_paired_unpaired.biom',
                         'ALL_Ross_combo_species_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in ALL_Ross_combo_species_WOL  =  88
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split(['Normal', 'Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'ALL_Ross_paired_species_WOL')

normal_be_eac_data_split(['Normal', 'Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'ALL_Ross_paired_genome_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in ALL_Ross_paired_species_WOL  =  88
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in ALL_Ross_paired_genome_WOL  =  88
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split(['Normal', 'Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_unpaired.biom',
                         'ALL_Ross_unpaired_species_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in ALL_Ross_unpaired_species_WOL  =  88
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### BE

# %% [markdown]
# ###### Used in paper

# %%
#WOL - scrubbed
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'BE_Ross_paired_species_WOL_scrubbed_rmBad',
                        remove_bad_microbes=True)
# Out:
#                     sample_name Patient Sample_type  \
# 0   Barretts_10_EGAF00000530875      10    Barretts
# 1   Barretts_11_EGAF00000586502      11    Barretts
# 2   Barretts_12_EGAF00000525202      12    Barretts
# 3   Barretts_13_EGAF00000525459      13    Barretts
# 4   Barretts_14_EGAF00000560129      14    Barretts
# 5   Barretts_14_EGAF00000814878      14    Barretts
# 6   Barretts_15_EGAF00000525456      15    Barretts
# 7   Barretts_15_EGAF00000814867      15    Barretts
# 8   Barretts_15_EGAF00000814879      15    Barretts
# 9   Barretts_16_EGAF00000525464      16    Barretts
# 10  Barretts_17_EGAF00000525463      17    Barretts
# 11  Barretts_17_EGAF00000814869      17    Barretts
# 12  Barretts_17_EGAF00000814882      17    Barretts
# 13  Barretts_17_EGAF00000814883      17    Barretts
# 14  Barretts_17_EGAF00000814884      17    Barretts
# 15  Barretts_18_EGAF00000560130      18    Barretts
# 16  Barretts_19_EGAF00000530863      19    Barretts
# 17   Barretts_1_EGAF00000501981       1    Barretts
# 18  Barretts_20_EGAF00000560125      20    Barretts
# 19  Barretts_21_EGAF00000560126      21    Barretts
# 20  Barretts_22_EGAF00000525458      22    Barretts
# 21  Barretts_23_EGAF00000501983      23    Barretts
# 22   Barretts_2_EGAF00000525461       2    Barretts
# 23   Barretts_2_EGAF00000814889       2    Barretts
# 24   Barretts_2_EGAF00000814890       2    Barretts
# 25   Barretts_3_EGAF00000560128       3    Barretts
# 26   Barretts_4_EGAF00000525457       4    Barretts
# 27   Barretts_4_EGAF00000814870       4    Barretts
# 28   Barretts_4_EGAF00000814871       4    Barretts
# 29   Barretts_5_EGAF00000525462       5    Barretts
# 30   Barretts_6_EGAF00000560127       6    Barretts
# 31   Barretts_7_EGAF00000501982       7    Barretts
# 32   Barretts_8_EGAF00000525460       8    Barretts
# 33   Barretts_8_EGAF00000814886       8    Barretts
# 34   Barretts_9_EGAF00000525201       9    Barretts
#
#                                         Centre Gender  \
# 0             Addenbrookes Hospital, Cambridge      F
# 1             Addenbrookes Hospital, Cambridge      M
# 2             Addenbrookes Hospital, Cambridge      M
# 3      Royal Surrey County Hospital, Guildford      F
# 4                   St Thomas Hospital, London      M
# 5                   St Thomas Hospital, London      M
# 6      Royal Surrey County Hospital, Guildford      M
# 7      Royal Surrey County Hospital, Guildford      M
# 8      Royal Surrey County Hospital, Guildford      M
# 9             Addenbrookes Hospital, Cambridge      M
# 10     Royal Surrey County Hospital, Guildford      M
# 11     Royal Surrey County Hospital, Guildford      M
# 12     Royal Surrey County Hospital, Guildford      M
# 13     Royal Surrey County Hospital, Guildford      M
# 14     Royal Surrey County Hospital, Guildford      M
# 15                  St Thomas Hospital, London      M
# 16            Addenbrookes Hospital, Cambridge      M
# 17            Addenbrookes Hospital, Cambridge      M
# 18        Edinburgh Royal Infirmary, Edinburgh      F
# 19     Royal Surrey County Hospital, Guildford      M
# 20     Royal Surrey County Hospital, Guildford      M
# 21            Addenbrookes Hospital, Cambridge      M
# 22                  St Thomas Hospital, London      F
# 23                  St Thomas Hospital, London      F
# 24                  St Thomas Hospital, London      F
# 25            Addenbrookes Hospital, Cambridge      M
# 26     Royal Surrey County Hospital, Guildford      M
# 27     Royal Surrey County Hospital, Guildford      M
# 28     Royal Surrey County Hospital, Guildford      M
# 29  Gloucestershire Royal Hospital, Gloucester      M
# 30  Gloucestershire Royal Hospital, Gloucester      M
# 31            Addenbrookes Hospital, Cambridge      M
# 32         Salford Royal Infirmary, Manchester      M
# 33         Salford Royal Infirmary, Manchester      M
# 34            Addenbrookes Hospital, Cambridge      M
#
#     Age_at_time_of_diagnosis    TNM7 Stage   Germline tissue  \
# 0                         79  T2N0M0    IB             Blood
# 1                         67  T4N2M0  IIIC  Normal esophagus
# 2                         65  T2N1M0   IIB             Blood
# 3                         61  T2N0M0    IB             Blood
# 4                         68  T3N1M0  IIIA             Blood
# 5                         68  T3N1M0  IIIA             Blood
# 6                         75  T3N3M1    IV             Blood
# 7                         75  T3N3M1    IV             Blood
# 8                         75  T3N3M1    IV             Blood
# 9                         65  T3N1M0  IIIA             Blood
# 10                        82  T3N1M0  IIIA             Blood
# 11                        82  T3N1M0  IIIA             Blood
# 12                        82  T3N1M0  IIIA             Blood
# 13                        82  T3N1M0  IIIA             Blood
# 14                        82  T3N1M0  IIIA             Blood
# 15                        61  T3N1M0  IIIA             Blood
# 16                        75  T3N0M0   IIA             Blood
# 17                        62  T2N0M0    IB             Blood
# 18                        79  T3N1M0  IIIA             Blood
# 19                        61  T1N0M0    IA             Blood
# 20                        50  T3N3M0  IIIC             Blood
# 21                        64  TxNxMx   NaN             Blood
# 22                        55  T2N1M0   IIB             Blood
# 23                        55  T2N1M0   IIB             Blood
# 24                        55  T2N1M0   IIB             Blood
# 25                        61  T3N2M1    IV             Blood
# 26                        58  T3N1M0  IIIA             Blood
# 27                        58  T3N1M0  IIIA             Blood
# 28                        58  T3N1M0  IIIA             Blood
# 29                        64  T1N0M0    IA             Blood
# 30                        73  T3N1Mx   NaN             Blood
# 31                        75  T3N0M0   IIA             Blood
# 32                        65  T2N0M0    IB             Blood
# 33                        65  T2N0M0    IB             Blood
# 34                        67  T1N0M0    IA             Blood
#
#     BE maximal length (cm)  ...  % aligned pairs median insert size  % mapQ=0  \
# 0                      4.0  ...            92.57              339.0      5.30
# 1                      3.0  ...            93.50              300.0      4.77
# 2                      NaN  ...            93.01              310.0      5.04
# 3                     15.0  ...            92.02              298.0      5.19
# 4                      6.0  ...            93.48              317.0      4.70
# 5                      6.0  ...            93.48              317.0      4.70
# 6                      9.0  ...            91.07              323.0      4.91
# 7                      9.0  ...            91.07              323.0      4.91
# 8                      9.0  ...            91.07              323.0      4.91
# 9                      NaN  ...            92.38              292.0      4.79
# 10                     6.0  ...            92.36              319.0      4.79
# 11                     6.0  ...            92.36              319.0      4.79
# 12                     6.0  ...            92.36              319.0      4.79
# 13                     6.0  ...            92.36              319.0      4.79
# 14                     6.0  ...            92.36              319.0      4.79
# 15                    10.0  ...            92.88              282.0      4.71
# 16                     NaN  ...            94.65              440.0      4.32
# 17                     NaN  ...            94.44              325.0      4.25
# 18                     NaN  ...            94.31              324.0      4.11
# 19                     5.0  ...            93.66              330.0      4.42
# 20                     3.0  ...            92.42              284.0      4.35
# 21                     2.0  ...            94.53              311.0      4.31
# 22                     6.0  ...            92.86              315.0      4.43
# 23                     6.0  ...            92.86              315.0      4.43
# 24                     6.0  ...            92.86              315.0      4.43
# 25                     NaN  ...            93.82              325.0      4.42
# 26                     3.0  ...            91.48              300.0      4.96
# 27                     3.0  ...            91.48              300.0      4.96
# 28                     3.0  ...            91.48              300.0      4.96
# 29                     NaN  ...            92.23              294.0      4.49
# 30                     NaN  ...            93.70              333.0      4.26
# 31                     NaN  ...            94.48              308.0      4.47
# 32                     5.0  ...            91.99              297.0      4.99
# 33                     5.0  ...            91.99              297.0      4.99
# 34                     5.0  ...            92.46              317.0      5.04
#
#     error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0            0.245                   55.76            0.975              NaN
# 1            0.231                   67.45            0.976              NaN
# 2            0.243                   57.20            0.975              NaN
# 3            0.222                   54.36            0.973              NaN
# 4            0.253                   61.75            0.976              NaN
# 5            0.253                   61.75            0.976              NaN
# 6            0.237                   67.85            0.977              NaN
# 7            0.237                   67.85            0.977              NaN
# 8            0.237                   67.85            0.977              NaN
# 9            0.234                   57.70            0.975              NaN
# 10           0.236                   71.36            0.977              NaN
# 11           0.236                   71.36            0.977              NaN
# 12           0.236                   71.36            0.977              NaN
# 13           0.236                   71.36            0.977              NaN
# 14           0.236                   71.36            0.977              NaN
# 15           0.240                   60.85            0.976              NaN
# 16           0.242                   73.95            0.979              NaN
# 17           0.227                   73.05            0.978              NaN
# 18           0.227                   62.97            0.977              NaN
# 19           0.238                   63.21            0.976              NaN
# 20           0.226                   56.27            0.975              NaN
# 21           0.221                   86.50            0.979              NaN
# 22           0.226                   56.30            0.975              NaN
# 23           0.226                   56.30            0.975              NaN
# 24           0.226                   56.30            0.975              NaN
# 25           0.238                   60.52            0.976              NaN
# 26           0.233                   55.51            0.974              NaN
# 27           0.233                   55.51            0.974              NaN
# 28           0.233                   55.51            0.974              NaN
# 29           0.237                   54.01            0.974              NaN
# 30           0.239                   58.54            0.975              NaN
# 31           0.235                   71.75            0.978              NaN
# 32           0.245                   57.43            0.975              NaN
# 33           0.245                   57.43            0.975              NaN
# 34           0.242                   61.34            0.976              NaN
#
#     Sample purity           EGA_ID      EGAIdentifier
# 0             0.8  EGAF00000530875  LP6007521-DNA_A01
# 1             0.6  EGAF00000586502  LP6005335-DNA_A01
# 2             0.3  EGAF00000525202  LP6007410-DNA_A01
# 3             0.6  EGAF00000525459  LP6005691-DNA_F01
# 4             0.3  EGAF00000560129  LP6005501-DNA_E01
# 5             0.3  EGAF00000814878  LP6008023-DNA_A01
# 6             0.7  EGAF00000525456  LP6005691-DNA_A01
# 7             0.7  EGAF00000814867  LP6008023-DNA_E01
# 8             0.7  EGAF00000814879  LP6008023-DNA_F01
# 9             0.8  EGAF00000525464  LP6005691-DNA_A02
# 10            0.7  EGAF00000525463  LP6005691-DNA_D01
# 11            0.7  EGAF00000814869  LP6008023-DNA_A02
# 12            0.7  EGAF00000814882  LP6008023-DNA_B02
# 13            0.7  EGAF00000814883  LP6008023-DNA_C02
# 14            0.7  EGAF00000814884  LP6008023-DNA_D02
# 15            0.3  EGAF00000560130  LP6005501-DNA_F01
# 16            0.5  EGAF00000530863  LP2000110-DNA_A01
# 17            0.6  EGAF00000501981          LP6007592
# 18            0.3  EGAF00000560125  LP6005501-DNA_A01
# 19            0.7  EGAF00000560126  LP6005501-DNA_B01
# 20            0.3  EGAF00000525458  LP6005691-DNA_B01
# 21            0.3  EGAF00000501983          LP6007598
# 22            0.3  EGAF00000525461  LP6005691-DNA_H01
# 23            0.3  EGAF00000814889  LP6008023-DNA_C03
# 24            0.3  EGAF00000814890  LP6008023-DNA_D03
# 25            0.4  EGAF00000560128  LP6005501-DNA_D01
# 26            0.7  EGAF00000525457  LP6005691-DNA_E01
# 27            0.7  EGAF00000814870  LP6008023-DNA_E02
# 28            0.7  EGAF00000814871  LP6008023-DNA_F02
# 29            0.8  EGAF00000525462  LP6005691-DNA_C01
# 30            0.9  EGAF00000560127  LP6005501-DNA_C01
# 31            0.7  EGAF00000501982          LP6007595
# 32            0.2  EGAF00000525460  LP6005691-DNA_G01
# 33            0.2  EGAF00000814886  LP6008023-DNA_H02
# 34            0.5  EGAF00000525201  LP6007405-DNA_A01
#
# [35 rows x 22 columns]
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            92.57
# 1  IIIC  Normal esophagus                     3.0  ...            93.50
# 2   IIB             Blood                     NaN  ...            93.01
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              339.0      5.30           0.245                   55.76
# 1              300.0      4.77           0.231                   67.45
# 2              310.0      5.04           0.243                   57.20
#
#    Callable genome  totalNumberSnps  Sample purity           EGA_ID  \
# 0            0.975              NaN            0.8  EGAF00000530875
# 1            0.976              NaN            0.6  EGAF00000586502
# 2            0.975              NaN            0.3  EGAF00000525202
#
#        EGAIdentifier
# 0  LP6007521-DNA_A01
# 1  LP6005335-DNA_A01
# 2  LP6007410-DNA_A01
#
# [3 rows x 22 columns]
# Total number of samples in BE_Ross_paired_species_WOL_scrubbed_rmBad  =  35
# <artifact: FeatureTable[Frequency] uuid: 08844b7f-5746-42e2-ba18-3062a7741207>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
#WOL - scrubbed
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'BE_Ross_ginny_species_WOL_scrubbed',
                        Ginny_list=True)
# Out:
#                     sample_name Patient Sample_type  \
# 0   Barretts_10_EGAF00000530875      10    Barretts
# 1   Barretts_11_EGAF00000586502      11    Barretts
# 2   Barretts_12_EGAF00000525202      12    Barretts
# 3   Barretts_13_EGAF00000525459      13    Barretts
# 4   Barretts_14_EGAF00000560129      14    Barretts
# 6   Barretts_15_EGAF00000525456      15    Barretts
# 9   Barretts_16_EGAF00000525464      16    Barretts
# 10  Barretts_17_EGAF00000525463      17    Barretts
# 15  Barretts_18_EGAF00000560130      18    Barretts
# 16  Barretts_19_EGAF00000530863      19    Barretts
# 17   Barretts_1_EGAF00000501981       1    Barretts
# 18  Barretts_20_EGAF00000560125      20    Barretts
# 19  Barretts_21_EGAF00000560126      21    Barretts
# 20  Barretts_22_EGAF00000525458      22    Barretts
# 21  Barretts_23_EGAF00000501983      23    Barretts
# 22   Barretts_2_EGAF00000525461       2    Barretts
# 25   Barretts_3_EGAF00000560128       3    Barretts
# 26   Barretts_4_EGAF00000525457       4    Barretts
# 29   Barretts_5_EGAF00000525462       5    Barretts
# 30   Barretts_6_EGAF00000560127       6    Barretts
# 31   Barretts_7_EGAF00000501982       7    Barretts
# 32   Barretts_8_EGAF00000525460       8    Barretts
# 34   Barretts_9_EGAF00000525201       9    Barretts
#
#                                         Centre Gender  \
# 0             Addenbrookes Hospital, Cambridge      F
# 1             Addenbrookes Hospital, Cambridge      M
# 2             Addenbrookes Hospital, Cambridge      M
# 3      Royal Surrey County Hospital, Guildford      F
# 4                   St Thomas Hospital, London      M
# 6      Royal Surrey County Hospital, Guildford      M
# 9             Addenbrookes Hospital, Cambridge      M
# 10     Royal Surrey County Hospital, Guildford      M
# 15                  St Thomas Hospital, London      M
# 16            Addenbrookes Hospital, Cambridge      M
# 17            Addenbrookes Hospital, Cambridge      M
# 18        Edinburgh Royal Infirmary, Edinburgh      F
# 19     Royal Surrey County Hospital, Guildford      M
# 20     Royal Surrey County Hospital, Guildford      M
# 21            Addenbrookes Hospital, Cambridge      M
# 22                  St Thomas Hospital, London      F
# 25            Addenbrookes Hospital, Cambridge      M
# 26     Royal Surrey County Hospital, Guildford      M
# 29  Gloucestershire Royal Hospital, Gloucester      M
# 30  Gloucestershire Royal Hospital, Gloucester      M
# 31            Addenbrookes Hospital, Cambridge      M
# 32         Salford Royal Infirmary, Manchester      M
# 34            Addenbrookes Hospital, Cambridge      M
#
#     Age_at_time_of_diagnosis    TNM7 Stage   Germline tissue  \
# 0                         79  T2N0M0    IB             Blood
# 1                         67  T4N2M0  IIIC  Normal esophagus
# 2                         65  T2N1M0   IIB             Blood
# 3                         61  T2N0M0    IB             Blood
# 4                         68  T3N1M0  IIIA             Blood
# 6                         75  T3N3M1    IV             Blood
# 9                         65  T3N1M0  IIIA             Blood
# 10                        82  T3N1M0  IIIA             Blood
# 15                        61  T3N1M0  IIIA             Blood
# 16                        75  T3N0M0   IIA             Blood
# 17                        62  T2N0M0    IB             Blood
# 18                        79  T3N1M0  IIIA             Blood
# 19                        61  T1N0M0    IA             Blood
# 20                        50  T3N3M0  IIIC             Blood
# 21                        64  TxNxMx   NaN             Blood
# 22                        55  T2N1M0   IIB             Blood
# 25                        61  T3N2M1    IV             Blood
# 26                        58  T3N1M0  IIIA             Blood
# 29                        64  T1N0M0    IA             Blood
# 30                        73  T3N1Mx   NaN             Blood
# 31                        75  T3N0M0   IIA             Blood
# 32                        65  T2N0M0    IB             Blood
# 34                        67  T1N0M0    IA             Blood
#
#     BE maximal length (cm)  ...  % aligned pairs median insert size  % mapQ=0  \
# 0                      4.0  ...            92.57              339.0      5.30
# 1                      3.0  ...            93.50              300.0      4.77
# 2                      NaN  ...            93.01              310.0      5.04
# 3                     15.0  ...            92.02              298.0      5.19
# 4                      6.0  ...            93.48              317.0      4.70
# 6                      9.0  ...            91.07              323.0      4.91
# 9                      NaN  ...            92.38              292.0      4.79
# 10                     6.0  ...            92.36              319.0      4.79
# 15                    10.0  ...            92.88              282.0      4.71
# 16                     NaN  ...            94.65              440.0      4.32
# 17                     NaN  ...            94.44              325.0      4.25
# 18                     NaN  ...            94.31              324.0      4.11
# 19                     5.0  ...            93.66              330.0      4.42
# 20                     3.0  ...            92.42              284.0      4.35
# 21                     2.0  ...            94.53              311.0      4.31
# 22                     6.0  ...            92.86              315.0      4.43
# 25                     NaN  ...            93.82              325.0      4.42
# 26                     3.0  ...            91.48              300.0      4.96
# 29                     NaN  ...            92.23              294.0      4.49
# 30                     NaN  ...            93.70              333.0      4.26
# 31                     NaN  ...            94.48              308.0      4.47
# 32                     5.0  ...            91.99              297.0      4.99
# 34                     5.0  ...            92.46              317.0      5.04
#
#     error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0            0.245                   55.76            0.975              NaN
# 1            0.231                   67.45            0.976              NaN
# 2            0.243                   57.20            0.975              NaN
# 3            0.222                   54.36            0.973              NaN
# 4            0.253                   61.75            0.976              NaN
# 6            0.237                   67.85            0.977              NaN
# 9            0.234                   57.70            0.975              NaN
# 10           0.236                   71.36            0.977              NaN
# 15           0.240                   60.85            0.976              NaN
# 16           0.242                   73.95            0.979              NaN
# 17           0.227                   73.05            0.978              NaN
# 18           0.227                   62.97            0.977              NaN
# 19           0.238                   63.21            0.976              NaN
# 20           0.226                   56.27            0.975              NaN
# 21           0.221                   86.50            0.979              NaN
# 22           0.226                   56.30            0.975              NaN
# 25           0.238                   60.52            0.976              NaN
# 26           0.233                   55.51            0.974              NaN
# 29           0.237                   54.01            0.974              NaN
# 30           0.239                   58.54            0.975              NaN
# 31           0.235                   71.75            0.978              NaN
# 32           0.245                   57.43            0.975              NaN
# 34           0.242                   61.34            0.976              NaN
#
#     Sample purity           EGA_ID      EGAIdentifier
# 0             0.8  EGAF00000530875  LP6007521-DNA_A01
# 1             0.6  EGAF00000586502  LP6005335-DNA_A01
# 2             0.3  EGAF00000525202  LP6007410-DNA_A01
# 3             0.6  EGAF00000525459  LP6005691-DNA_F01
# 4             0.3  EGAF00000560129  LP6005501-DNA_E01
# 6             0.7  EGAF00000525456  LP6005691-DNA_A01
# 9             0.8  EGAF00000525464  LP6005691-DNA_A02
# 10            0.7  EGAF00000525463  LP6005691-DNA_D01
# 15            0.3  EGAF00000560130  LP6005501-DNA_F01
# 16            0.5  EGAF00000530863  LP2000110-DNA_A01
# 17            0.6  EGAF00000501981          LP6007592
# 18            0.3  EGAF00000560125  LP6005501-DNA_A01
# 19            0.7  EGAF00000560126  LP6005501-DNA_B01
# 20            0.3  EGAF00000525458  LP6005691-DNA_B01
# 21            0.3  EGAF00000501983          LP6007598
# 22            0.3  EGAF00000525461  LP6005691-DNA_H01
# 25            0.4  EGAF00000560128  LP6005501-DNA_D01
# 26            0.7  EGAF00000525457  LP6005691-DNA_E01
# 29            0.8  EGAF00000525462  LP6005691-DNA_C01
# 30            0.9  EGAF00000560127  LP6005501-DNA_C01
# 31            0.7  EGAF00000501982          LP6007595
# 32            0.2  EGAF00000525460  LP6005691-DNA_G01
# 34            0.5  EGAF00000525201  LP6007405-DNA_A01
#
# [23 rows x 22 columns]
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            92.57
# 1  IIIC  Normal esophagus                     3.0  ...            93.50
# 2   IIB             Blood                     NaN  ...            93.01
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              339.0      5.30           0.245                   55.76
# 1              300.0      4.77           0.231                   67.45
# 2              310.0      5.04           0.243                   57.20
#
#    Callable genome  totalNumberSnps  Sample purity           EGA_ID  \
# 0            0.975              NaN            0.8  EGAF00000530875
# 1            0.976              NaN            0.6  EGAF00000586502
# 2            0.975              NaN            0.3  EGAF00000525202
#
#        EGAIdentifier
# 0  LP6007521-DNA_A01
# 1  LP6005335-DNA_A01
# 2  LP6007410-DNA_A01
#
# [3 rows x 22 columns]
# Total number of samples in BE_Ross_ginny_species_WOL_scrubbed  =  23
# <artifact: FeatureTable[Frequency] uuid: 14598780-af41-4de2-a1d3-c094f45ea852>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not in paper

# %%
#WOL - scrubbed
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'BE_Ross_paired_species_WOL_scrubbed')

# %%
#WOL - scrubbed
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'BE_exact_Ross_paired_genome_WOL_scrubbed',
                        exact_pairs=True)

#WOL
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'BE_Ross_paired_species_WOL')

normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'BE_exact_Ross_paired_species_WOL',
                         exact_pairs=True)

normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'BE_Ross_paired_genome_WOL')

normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'BE_zebra_Ross_paired_genome_WOL',
                        zebra = 'Ross_WOL')

normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'BE_zebra_exact_Ross_paired_genome_WOL',
                         exact_pairs=True,
                        zebra = 'Ross_WOL')

#Rep200
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_rep200_R1_R2_paired.biom',
                         'BE_Ross_paired_species_rep200')

normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_rep200_R1_R2_paired.biom',
                         'BE_exact_Ross_paired_species_rep200',
                        exact_pairs=True)
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_exact_Ross_paired_genome_WOL_scrubbed  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_Ross_paired_species_WOL  =  35
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_exact_Ross_paired_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_Ross_paired_genome_WOL  =  35
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# Total number of samples in BE_zebra_Ross_paired_genome_WOL  =  35
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_zebra_exact_Ross_paired_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_Ross_paired_species_rep200  =  35
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_exact_Ross_paired_species_rep200  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_combo_R1_R2_paired_unpaired.biom',
                         'BE_Ross_combo_species_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_Ross_combo_species_WOL  =  35
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split(['Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_unpaired.biom',
                         'BE_Ross_unpaired_species_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_Ross_unpaired_species_WOL  =  35
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### EAC

# %% [markdown]
# ###### Used in paper

# %%
#WOL - scrubbed
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_paired_species_WOL_scrubbed_rmBad',
                        remove_bad_microbes=True)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_species_WOL_scrubbed_rmBad  =  30
# <artifact: FeatureTable[Frequency] uuid: 49ed5da6-ab3f-48dc-9ed7-8a6cce391086>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
#WOL - scrubbed
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_ginny_species_WOL_scrubbed',
                        Ginny_list=True)
# Out:
#                  sample_name Patient Sample_type  \
# 70  Tumor_10_EGAF00000530893      10         EAC
# 71  Tumor_11_EGAF00000586547      11         EAC
# 72  Tumor_12_EGAF00000525525      12         EAC
# 73  Tumor_13_EGAF00000525466      13         EAC
# 74  Tumor_14_EGAF00000560172      14         EAC
# 77  Tumor_15_EGAF00000525475      15         EAC
# 80  Tumor_16_EGAF00000525474      16         EAC
# 81  Tumor_17_EGAF00000525479      17         EAC
# 82  Tumor_18_EGAF00000560173      18         EAC
# 83  Tumor_19_EGAF00000530869      19         EAC
# 84   Tumor_1_EGAF00000501976       1         EAC
# 85  Tumor_20_EGAF00000560131      20         EAC
# 86  Tumor_21_EGAF00000560132      21         EAC
# 87  Tumor_22_EGAF00000525477      22         EAC
# 88  Tumor_23_EGAF00000501978      23         EAC
# 89   Tumor_2_EGAF00000525468       2         EAC
# 90   Tumor_3_EGAF00000560133       3         EAC
# 91   Tumor_4_EGAF00000525476       4         EAC
# 93   Tumor_5_EGAF00000525478       5         EAC
# 94   Tumor_6_EGAF00000560171       6         EAC
# 95   Tumor_7_EGAF00000501977       7         EAC
# 96   Tumor_8_EGAF00000525467       8         EAC
# 99   Tumor_9_EGAF00000525188       9         EAC
#
#                                         Centre Gender  \
# 70            Addenbrookes Hospital, Cambridge      F
# 71            Addenbrookes Hospital, Cambridge      M
# 72            Addenbrookes Hospital, Cambridge      M
# 73     Royal Surrey County Hospital, Guildford      F
# 74                  St Thomas Hospital, London      M
# 77     Royal Surrey County Hospital, Guildford      M
# 80            Addenbrookes Hospital, Cambridge      M
# 81     Royal Surrey County Hospital, Guildford      M
# 82                  St Thomas Hospital, London      M
# 83            Addenbrookes Hospital, Cambridge      M
# 84            Addenbrookes Hospital, Cambridge      M
# 85        Edinburgh Royal Infirmary, Edinburgh      F
# 86     Royal Surrey County Hospital, Guildford      M
# 87     Royal Surrey County Hospital, Guildford      M
# 88            Addenbrookes Hospital, Cambridge      M
# 89                  St Thomas Hospital, London      F
# 90            Addenbrookes Hospital, Cambridge      M
# 91     Royal Surrey County Hospital, Guildford      M
# 93  Gloucestershire Royal Hospital, Gloucester      M
# 94  Gloucestershire Royal Hospital, Gloucester      M
# 95            Addenbrookes Hospital, Cambridge      M
# 96         Salford Royal Infirmary, Manchester      M
# 99            Addenbrookes Hospital, Cambridge      M
#
#     Age_at_time_of_diagnosis    TNM7 Stage   Germline tissue  \
# 70                        79  T2N0M0    IB             Blood
# 71                        67  T4N2M0  IIIC  Normal esophagus
# 72                        65  T2N1M0   IIB             Blood
# 73                        61  T2N0M0    IB             Blood
# 74                        68  T3N1M0  IIIA             Blood
# 77                        75  T3N3M1    IV             Blood
# 80                        65  T3N1M0  IIIA             Blood
# 81                        82  T3N1M0  IIIA             Blood
# 82                        61  T3N1M0  IIIA             Blood
# 83                        75  T3N0M0   IIA             Blood
# 84                        62  T2N0M0    IB             Blood
# 85                        79  T3N1M0  IIIA             Blood
# 86                        61  T1N0M0    IA             Blood
# 87                        50  T3N3M0  IIIC             Blood
# 88                        64  TxNxMx   NaN             Blood
# 89                        55  T2N1M0   IIB             Blood
# 90                        61  T3N2M1    IV             Blood
# 91                        58  T3N1M0  IIIA             Blood
# 93                        64  T1N0M0    IA             Blood
# 94                        73  T3N1Mx   NaN             Blood
# 95                        75  T3N0M0   IIA             Blood
# 96                        65  T2N0M0    IB             Blood
# 99                        67  T1N0M0    IA             Blood
#
#     BE maximal length (cm)  ...  % aligned pairs median insert size  % mapQ=0  \
# 70                     4.0  ...            93.72              315.0      4.57
# 71                     3.0  ...            93.70              306.0      5.03
# 72                     NaN  ...            93.33              299.0      4.91
# 73                    15.0  ...            93.49              310.0      4.53
# 74                     6.0  ...            93.87              314.0      4.63
# 77                     9.0  ...            90.40              308.0      6.36
# 80                     NaN  ...            92.44              308.0      5.12
# 81                     6.0  ...            92.48              310.0      5.05
# 82                    10.0  ...            93.91              312.0      5.46
# 83                     NaN  ...            94.76              430.0      4.28
# 84                     NaN  ...            95.13              297.0      4.27
# 85                     NaN  ...            94.00              308.0      4.67
# 86                     5.0  ...            93.79              308.0      4.80
# 87                     3.0  ...            92.89              308.0      4.48
# 88                     2.0  ...            94.48              305.0      4.18
# 89                     6.0  ...            92.98              303.0      5.17
# 90                     NaN  ...            92.92              312.0      5.49
# 91                     3.0  ...            93.00              313.0      4.13
# 93                     NaN  ...            92.11              305.0      4.77
# 94                     NaN  ...            93.19              309.0      5.30
# 95                     NaN  ...            94.94              313.0      4.38
# 96                     5.0  ...            92.75              307.0      5.10
# 99                     5.0  ...            93.67              306.0      4.72
#
#     error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 70           0.229                   58.65            0.975              NaN
# 71           0.224                   58.86            0.972              NaN
# 72           0.235                   64.32            0.976              NaN
# 73           0.217                   82.11            0.978              NaN
# 74           0.254                   63.20            0.976              NaN
# 77           0.240                   83.40            0.973              NaN
# 80           0.233                   65.23            0.975              NaN
# 81           0.239                   62.44            0.975              NaN
# 82           0.706                   76.41            0.978              NaN
# 83           0.232                   80.45            0.979              NaN
# 84           0.225                   75.79            0.978              NaN
# 85           0.231                   77.76            0.978              NaN
# 86           0.251                   64.93            0.976              NaN
# 87           0.222                   63.04            0.975              NaN
# 88           0.216                   82.51            0.978              NaN
# 89           0.220                   89.29            0.977              NaN
# 90           0.288                   60.89            0.975              NaN
# 91           0.215                   76.81            0.978              NaN
# 93           0.237                   59.99            0.975              NaN
# 94           0.265                   66.88            0.976              NaN
# 95           0.225                   76.14            0.978              NaN
# 96           0.231                   81.73            0.976              NaN
# 99           0.226                   66.52            0.976              NaN
#
#     Sample purity           EGA_ID      EGAIdentifier
# 70            0.5  EGAF00000530893  LP6007520-DNA_A01
# 71            0.7  EGAF00000586547  LP6005334-DNA_A03
# 72            0.4  EGAF00000525525  LP6007409-DNA_A01
# 73            0.5  EGAF00000525466  LP6005690-DNA_F01
# 74            0.9  EGAF00000560172  LP6005500-DNA_E01
# 77            0.7  EGAF00000525475  LP6005690-DNA_C01
# 80            0.8  EGAF00000525474  LP6005690-DNA_F03
# 81            0.8  EGAF00000525479  LP6005690-DNA_B02
# 82            0.4  EGAF00000560173  LP6005500-DNA_F01
# 83            0.4  EGAF00000530869  LP2000104-DNA_A01
# 84            0.6  EGAF00000501976          LP6007591
# 85            0.5  EGAF00000560131  LP6005500-DNA_A01
# 86            0.6  EGAF00000560132  LP6005500-DNA_B01
# 87            0.7  EGAF00000525477  LP6005690-DNA_E01
# 88            0.5  EGAF00000501978          LP6007597
# 89            0.6  EGAF00000525468  LP6005690-DNA_H01
# 90            0.3  EGAF00000560133  LP6005500-DNA_D01
# 91            0.7  EGAF00000525476  LP6005690-DNA_D01
# 93            0.7  EGAF00000525478  LP6005690-DNA_A02
# 94            0.2  EGAF00000560171  LP6005500-DNA_C01
# 95            0.5  EGAF00000501977          LP6007594
# 96            0.9  EGAF00000525467  LP6005690-DNA_G01
# 99            0.6  EGAF00000525188  LP6007404-DNA_A01
#
# [23 rows x 22 columns]
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  ...  % aligned pairs  \
# 0    IB             Blood                     4.0  ...            93.72
# 1  IIIC  Normal esophagus                     3.0  ...            93.70
# 2   IIB             Blood                     NaN  ...            93.33
#
#   median insert size  % mapQ=0  error rate HiQ  genome coverage mapQ>3  \
# 0              315.0      4.57           0.229                   58.65
# 1              306.0      5.03           0.224                   58.86
# 2              299.0      4.91           0.235                   64.32
#
#    Callable genome  totalNumberSnps  Sample purity           EGA_ID  \
# 0            0.975              NaN            0.5  EGAF00000530893
# 1            0.972              NaN            0.7  EGAF00000586547
# 2            0.976              NaN            0.4  EGAF00000525525
#
#        EGAIdentifier
# 0  LP6007520-DNA_A01
# 1  LP6005334-DNA_A03
# 2  LP6007409-DNA_A01
#
# [3 rows x 22 columns]
# Total number of samples in EAC_Ross_ginny_species_WOL_scrubbed  =  23
# <artifact: FeatureTable[Frequency] uuid: 69577db9-21bc-4666-945f-ff410ed88bba>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:127: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ###### Not in paper

# %%
#WOL - scrubbed
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_paired_species_WOL_scrubbed')
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_species_WOL_scrubbed  =  30
# <artifact: FeatureTable[Frequency] uuid: 47764dbc-610f-41f9-87ff-09493f70a123>
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:103: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
#WOL - scrubbed
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired_scrubbed/feature-table.biom',
                         'EAC_Ross_paired_genome_WOL_scrubbed')

#WOL
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'EAC_Ross_paired_species_WOL')

normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'EAC_Ross_paired_genome_WOL')

normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'EAC_exact_Ross_paired_species_WOL',
                         exact_pairs=True)

normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'EAC_zebra_Ross_paired_genome_WOL',
                        zebra = 'Ross_WOL')

normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'EAC_zebra_exact_Ross_paired_genome_WOL',
                         exact_pairs=True,
                        zebra = 'Ross_WOL')

#Rep200
normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_rep200_R1_R2_paired.biom',
                         'EAC_Ross_paired_species_rep200')

normal_be_eac_data_split(['EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_rep200_R1_R2_paired.biom',
                         'EAC_exact_Ross_paired_species_rep200',
                         exact_pairs = True)
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_genome_WOL_scrubbed  =  30
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_species_WOL  =  30
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_genome_WOL  =  30
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           950,588,085           93.72              315.0     4.57
# 1           995,657,497            93.7              306.0     5.03
# 2         1,068,844,258           93.33              299.0     4.91
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.229                  58.65           0.975             NaN
# 1          0.224                  58.86           0.972             NaN
# 2          0.235                  64.32           0.976             NaN
#
#   Sample purity
# 0           0.5
# 1           0.7
# 2           0.4
# Total number of samples in EAC_exact_Ross_paired_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_zebra_Ross_paired_genome_WOL  =  30
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           950,588,085           93.72              315.0     4.57
# 1           995,657,497            93.7              306.0     5.03
# 2         1,068,844,258           93.33              299.0     4.91
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.229                  58.65           0.975             NaN
# 1          0.224                  58.86           0.972             NaN
# 2          0.235                  64.32           0.976             NaN
#
#   Sample purity
# 0           0.5
# 1           0.7
# 2           0.4
# Total number of samples in EAC_zebra_exact_Ross_paired_genome_WOL  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_paired_species_rep200  =  30
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           950,588,085           93.72              315.0     4.57
# 1           995,657,497            93.7              306.0     5.03
# 2         1,068,844,258           93.33              299.0     4.91
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.229                  58.65           0.975             NaN
# 1          0.224                  58.86           0.972             NaN
# 2          0.235                  64.32           0.976             NaN
#
#   Sample purity
# 0           0.5
# 1           0.7
# 2           0.4
# Total number of samples in EAC_exact_Ross_paired_species_rep200  =  23
# /Users/cguccion/Dropbox/current_Fall23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split('EAC',
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_combo_R1_R2_paired_unpaired.biom',
                         'EAC_Ross_combo_species_WOL')
# Out:
#                 sample_name Patient Sample_type  \
# 0  Tumor_10_EGAF00000530893      10         EAC
# 1  Tumor_11_EGAF00000586547      11         EAC
# 2  Tumor_12_EGAF00000525525      12         EAC
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           950,588,085            93.72               315.0      4.57
# 1           995,657,497            93.70               306.0      5.03
# 2         1,068,844,258            93.33               299.0      4.91
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.229                   58.65            0.975              NaN
# 1           0.224                   58.86            0.972              NaN
# 2           0.235                   64.32            0.976              NaN
#
#    Sample purity
# 0            0.5
# 1            0.7
# 2            0.4
# Total number of samples in EAC_Ross_combo_species_WOL  =  30
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) Normal

# %%
normal_be_eac_data_split('Normal',
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_combo_R1_R2_paired_unpaired.biom',
                         'Norm_Ross_combo_species_WOL')
# Out:
#                  sample_name Patient Sample_type  \
# 0  Normal_10_EGAF00000530908      10      Normal
# 1  Normal_11_EGAF00000586533      11      Normal
# 2  Normal_12_EGAF00000525507      12      Normal
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           807,792,398            92.49               296.0      5.03
# 1           639,793,060            92.22               315.0      4.88
# 2           559,984,669            88.64               299.0      5.09
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   48.64            0.968        3523708.0
# 1           0.241                   37.77            0.969        3541117.0
# 2           0.257                   32.15            0.964        3491591.0
#
#    Sample purity
# 0            NaN
# 1            NaN
# 2            NaN
# Total number of samples in Norm_Ross_combo_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %%
normal_be_eac_data_split(['Normal'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'Norm_Ross_paired_species_WOL')
# Out:
#                  sample_name Patient Sample_type  \
# 0  Normal_10_EGAF00000530908      10      Normal
# 1  Normal_11_EGAF00000586533      11      Normal
# 2  Normal_12_EGAF00000525507      12      Normal
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           807,792,398            92.49               296.0      5.03
# 1           639,793,060            92.22               315.0      4.88
# 2           559,984,669            88.64               299.0      5.09
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   48.64            0.968        3523708.0
# 1           0.241                   37.77            0.969        3541117.0
# 2           0.257                   32.15            0.964        3491591.0
#
#    Sample purity
# 0            NaN
# 1            NaN
# 2            NaN
# Total number of samples in Norm_Ross_paired_species_WOL  =  23
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) Normal + BE

# %%
normal_be_eac_data_split(['Normal', 'Barretts'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'Norm_BE_Ross_paired_species_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in Norm_BE_Ross_paired_species_WOL  =  58
# /Users/cguccion/Dropbox/current_Spring23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:32: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) BE + EAC

# %%
normal_be_eac_data_split(['Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'BE_EAC_Ross_paired_species_WOL')

normal_be_eac_data_split(['Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'BE_EAC_Ross_paired_genome_WOL')
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_EAC_Ross_paired_species_WOL  =  65
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender  Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                        79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                        67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                        65  T2N1M0
#
#   Stage   Germline tissue  BE maximal length (cm)  Tumor length (mm)  \
# 0    IB             Blood                     4.0               15.0
# 1  IIIC  Normal esophagus                     3.0               70.0
# 2   IIB             Blood                     NaN               29.0
#
#   purity-filtered pairs  % aligned pairs  median insert size  % mapQ=0  \
# 0           935,820,463            92.57               339.0      5.30
# 1         1,135,954,265            93.50               300.0      4.77
# 2           955,544,208            93.01               310.0      5.04
#
#    error rate HiQ  genome coverage mapQ>3  Callable genome  totalNumberSnps  \
# 0           0.245                   55.76            0.975              NaN
# 1           0.231                   67.45            0.976              NaN
# 2           0.243                   57.20            0.975              NaN
#
#    Sample purity
# 0            0.8
# 1            0.6
# 2            0.3
# Total number of samples in BE_EAC_Ross_paired_genome_WOL  =  65
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ##### (Not used in paper) Exact Pairs of BE/EAC
# Note: Still unclear why some have multiple BE samples in the paper, so chose random BE for each patient

# %%
normal_be_eac_data_split(['Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/species_WOL_R1_R2_paired.biom',
                         'BE_EAC_exact_Ross_paired_species_WOL',
                         exact_pairs=True)

normal_be_eac_data_split(['Barretts', 'EAC'],
                         os.getcwd() + '/qiita_downloads/qiitaTBD_Norm_BE_EAC/genome_WOL_R1_R2_paired.biom',
                         'BE_EAC_exact_Ross_paired_genome_WOL',
                        exact_pairs=True)
# Out:
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_EAC_exact_Ross_paired_species_WOL  =  46
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                    sample_name Patient Sample_type  \
# 0  Barretts_10_EGAF00000530875      10    Barretts
# 1  Barretts_11_EGAF00000586502      11    Barretts
# 2  Barretts_12_EGAF00000525202      12    Barretts
#
#                              Centre Gender Age_at_time_of_diagnosis    TNM7  \
# 0  Addenbrookes Hospital, Cambridge      F                       79  T2N0M0
# 1  Addenbrookes Hospital, Cambridge      M                       67  T4N2M0
# 2  Addenbrookes Hospital, Cambridge      M                       65  T2N1M0
#
#   Stage   Germline tissue BE maximal length (cm) Tumor length (mm)  \
# 0    IB             Blood                    4.0              15.0
# 1  IIIC  Normal esophagus                    3.0              70.0
# 2   IIB             Blood                    NaN              29.0
#
#   purity-filtered pairs % aligned pairs median insert size % mapQ=0  \
# 0           935,820,463           92.57              339.0      5.3
# 1         1,135,954,265            93.5              300.0     4.77
# 2           955,544,208           93.01              310.0     5.04
#
#   error rate HiQ genome coverage mapQ>3 Callable genome totalNumberSnps  \
# 0          0.245                  55.76           0.975             NaN
# 1          0.231                  67.45           0.976             NaN
# 2          0.243                   57.2           0.975             NaN
#
#   Sample purity
# 0           0.8
# 1           0.6
# 2           0.3
# Total number of samples in BE_EAC_exact_Ross_paired_genome_WOL  =  46
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ### (Supp?) From Sam: Barrett's Esophgous Progressors/Non Progressors: using MetaPhlan4
# Paulson, T. G. et al. Somatic whole genome dynamics of precancer in Barrett’s esophagus reveals features associated with disease progression. Nature Communications vol. 13 (2022) https://doi.org/10.1038/s41467-022-29767-7

# %% [markdown]
# ##### Barrett's Esophgous

# %%
#Relative Abudnace
Sam_BE_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_species_MP')

#Counts
Sam_BE_data_split(['NP', 'Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_species_MP_counts', True)
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
# Total number of samples in BE_species_MP  =  202
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
# Total number of samples in BE_species_MP_counts  =  202

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors

# %%
Sam_BE_data_split(['NP',], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_NP_species_MP')

#Counts
Sam_BE_data_split(['NP'], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_NP_species_MP_counts', True)
# Out:
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
# Total number of samples in BE_NP_species_MP  =  111
#              sample_name               race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01  White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02  White_nonHispanic      M         17         T1
# 2  14598.PCGA.1064.BE.03  White_nonHispanic      M         17         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  17-24987N-105W-BLD                4             23567
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               87.07           14598
# Total number of samples in BE_NP_species_MP_counts  =  111

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T1

# %%
Sam_BE_data_split(['NP',], ['T1'], 
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_NP_T1_species_MP')

#Counts
Sam_BE_data_split(['NP'], ['T1'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_NP_T1_species_MP_counts', True)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
# Total number of samples in BE_NP_T1_species_MP  =  53
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.01      White_nonHispanic      M         17         T1
# 1  14598.PCGA.1064.BE.02      White_nonHispanic      M         17         T1
# 2  14598.PCGA.1067.BE.01  Asian_PacificIslander      M         55         T1
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                3             23561
# 1            1  17-24987N-105W-BLD                7             23564
# 2            1  55-25056N-204U-BLD                3             23611
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               78.83           14598
# 1                NP               78.83           14598
# 2                NP               53.23           14598
# Total number of samples in BE_NP_T1_species_MP_counts  =  53

# %% [markdown]
# ##### Barrett's Esophgous Non Progressors T2

# %%
Sam_BE_data_split(['NP',], ['T2'], 
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_NP_T2_species_MP')

#Counts
Sam_BE_data_split(['NP'], ['T2'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_NP_T2_species_MP_counts', True)
# Out:
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
# Total number of samples in BE_NP_T2_species_MP  =  58
#              sample_name                   race gender  patientid sampletype  \
# 0  14598.PCGA.1064.BE.03      White_nonHispanic      M         17         T2
# 1  14598.PCGA.1064.BE.04      White_nonHispanic      M         17         T2
# 2  14598.PCGA.1067.BE.02  Asian_PacificIslander      M         55         T2
#
#    ismainstudy        pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  17-24987N-105W-BLD                4             23567
# 1            1  17-24987N-105W-BLD                1             24933
# 2            1  55-25056N-204U-BLD                1             23614
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0                NP               87.07           14598
# 1                NP               87.07           14598
# 2                NP               57.07           14598
# Total number of samples in BE_NP_T2_species_MP_counts  =  58

# %% [markdown]
# ##### Barrett's Esophgous Progressors

# %%
Sam_BE_data_split(['Prog',], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_Prog_species_MP')

#Counts
Sam_BE_data_split(['Prog'], ['T1', 'T2'], #, 'LongFollowUp'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_Prog_species_MP_counts', True)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               56.25           14598
# Total number of samples in BE_Prog_species_MP  =  91
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  42-24954N-53L-GST                5             24289
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               56.25           14598
# Total number of samples in BE_Prog_species_MP_counts  =  91

# %% [markdown]
# ##### Barrett's Esophgous Progressors T1

# %%
Sam_BE_data_split(['Prog',], ['T1'], 
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_Prog_T1_species_MP')

#Counts
Sam_BE_data_split(['Prog'], ['T1'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_Prog_T1_species_MP_counts', True)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
# Total number of samples in BE_Prog_T1_species_MP  =  40
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.03  Other_Unknown      M         42         T1
# 1  14598.PCGA.1065.BE.04  Other_Unknown      M         42         T1
# 2  14598.PCGA.1066.BE.01  Other_Unknown      F         43         T1
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24289
# 1            1  42-24954N-53L-GST                3             24292
# 2            1  43-24956N-29P-GST                1             23585
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               56.25           14598
# 1              Prog               56.25           14598
# 2              Prog               64.11           14598
# Total number of samples in BE_Prog_T1_species_MP_counts  =  40

# %% [markdown]
# ##### Barrett's Esophgous Progressors T2

# %%
Sam_BE_data_split(['Prog',], ['T2'], 
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/metaphlan.wide.species.csv',
              'BE_Prog_T2_species_MP')

#Counts
Sam_BE_data_split(['Prog'], ['T2'],
              '/Users/cguccion/Dropbox/Storage/RawData/23_06_23_Hutch_BE_Sam_Data/2023-06-23-metaphlan-analysis-bundle/convert_counts/metaphlan.wide.counts.species.csv',
              'BE_Prog_T2_species_MP_counts', True)
# Out:
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
# Total number of samples in BE_Prog_T2_species_MP  =  51
#              sample_name           race gender  patientid sampletype  \
# 0  14598.PCGA.1065.BE.01  Other_Unknown      M         42         T2
# 1  14598.PCGA.1065.BE.02  Other_Unknown      M         42         T2
# 2  14598.PCGA.1066.BE.02  Other_Unknown      F         43         T2
#
#    ismainstudy       pairednormal  distancefromgej  orginal_sampleid  \
# 0            1  42-24954N-53L-GST                5             24283
# 1            1  42-24954N-53L-GST                1             24286
# 2            1  43-24956N-29P-GST                4             23593
#
#   progressionstatus  patientageatsample  qiita_study_id
# 0              Prog               57.65           14598
# 1              Prog               57.65           14598
# 2              Prog               65.07           14598
# Total number of samples in BE_Prog_T2_species_MP_counts  =  51

# %% [markdown]
# ### Not used in paper: TCGA EAC: BAD
# BAD: From TCGA, not exact paper

# %%
eac_tcga_data_split(os.getcwd() +'/qiita_downloads/qiita14990_EAC_TCGA/species_WOL/feature-table.biom',
                'EAC_TCGA_species_WOL')

eac_tcga_data_split(os.getcwd() +'/qiita_downloads/qiita14990_EAC_TCGA/171534_none_WOL.biom',
                'EAC_TCGA_zebra_genome_WOL',
                zebra = 'EAC_TCGA_WOL')
# Out:
#                       sample_name          race       size  gender  \
# 0  14990.64226f74c281925c8815b407         white  192795648  female
# 1  14990.6422776e8c11cc752762f39b         white  143024713    male
# 2  14990.6422782f8c11cc752762f3a3  not reported  221282761  female
#
#         case_id             project     ethnicity  \
# 0  TCGA-L5-A4OG  cguccione/tcga-eac  not reported
# 1  TCGA-L5-A4OI  cguccione/tcga-eac  not reported
# 2  TCGA-L5-A43M  cguccione/tcga-eac  not reported
#
#                      aliquot_id    sample_type  \
# 0  TCGA-L5-A4OG-01A-11D-A267-26  Primary Tumor
# 1  TCGA-L5-A4OI-01A-11D-A267-26  Primary Tumor
# 2  TCGA-L5-A43M-01A-11D-A248-26  Primary Tumor
#
#                             sample_uuid                          aliquot_uuid  \
# 0  e8e44c65-b4e4-4688-a217-206905e68a7f  04c91c91-e55a-4075-b08a-f80568bb4a7b
# 1  1b1cbb34-da71-4441-b1a1-c936e8f04c73  8d5a0d62-d9c1-46d1-9b81-685293b45e6b
# 2  aeec137a-e929-439c-b7e7-33943cffb642  97721561-b3ce-4b56-b0d2-b7c70e978526
#
#                    disease_type primary_site vital_status investigation  \
# 0  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
# 1  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
# 2  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
#
#                         host_subject_id  qiita_study_id
# 0  eb4ad376-4cc1-4d2c-9b93-ad2b082c77c4           14990
# 1  cb2af13b-cbed-4657-8fd4-fed8db375cba           14990
# 2  29da08f4-c9e2-4e7a-9733-b4ec5b9c5f13           14990
# Total number of samples in EAC_TCGA_species_WOL  =  19
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                       sample_name          race       size  gender  \
# 0  14990.64226f74c281925c8815b407         white  192795648  female
# 1  14990.6422776e8c11cc752762f39b         white  143024713    male
# 2  14990.6422782f8c11cc752762f3a3  not reported  221282761  female
#
#         case_id             project     ethnicity  \
# 0  TCGA-L5-A4OG  cguccione/tcga-eac  not reported
# 1  TCGA-L5-A4OI  cguccione/tcga-eac  not reported
# 2  TCGA-L5-A43M  cguccione/tcga-eac  not reported
#
#                      aliquot_id    sample_type  \
# 0  TCGA-L5-A4OG-01A-11D-A267-26  Primary Tumor
# 1  TCGA-L5-A4OI-01A-11D-A267-26  Primary Tumor
# 2  TCGA-L5-A43M-01A-11D-A248-26  Primary Tumor
#
#                             sample_uuid                          aliquot_uuid  \
# 0  e8e44c65-b4e4-4688-a217-206905e68a7f  04c91c91-e55a-4075-b08a-f80568bb4a7b
# 1  1b1cbb34-da71-4441-b1a1-c936e8f04c73  8d5a0d62-d9c1-46d1-9b81-685293b45e6b
# 2  aeec137a-e929-439c-b7e7-33943cffb642  97721561-b3ce-4b56-b0d2-b7c70e978526
#
#                    disease_type primary_site vital_status investigation  \
# 0  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
# 1  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
# 2  Adenomas and Adenocarcinomas    Esophagus        Alive     TCGA-ESCA
#
#                         host_subject_id  qiita_study_id
# 0  eb4ad376-4cc1-4d2c-9b93-ad2b082c77c4           14990
# 1  cb2af13b-cbed-4657-8fd4-fed8db375cba           14990
# 2  29da08f4-c9e2-4e7a-9733-b4ec5b9c5f13           14990
# Total number of samples in EAC_TCGA_zebra_genome_WOL  =  19
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:54: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()

# %% [markdown]
# ### Not used in paper: EAC : OLD ICGC, 14521
# From ICGC , not exact paper

# %%
eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147030_species_WOL.biom',
                'EAC_species_WOL')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147032_genome_WOL.biom',
                'EAC_genome_WOL')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147032_genome_WOL.biom',
                'EAC_zebra_genome_WOL',
              zebra= 'EAC_WOL')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147030_species_WOL.biom',
                'EAC_species_23_WOL',
              trim = 48)

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147032_genome_WOL.biom',
                'EAC_genome_zebra_23_WOL',
               zebra = 'EAC_WOL',
              trim = 48)

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147032_genome_WOL.biom',
                'EAC_genome_WOL_lowStage',
              stage='low')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147032_genome_WOL.biom',
                'EAC_genome_WOL_highStage',
              stage='high')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147030_species_WOL.biom',
                'EAC_species_WOL_lowStage',
              stage = 'low')

eac_data_split(os.getcwd() +'/qiita_downloads/qiita14521_EAC_ICGC/147030_species_WOL.biom',
                'EAC_species_WOL_highStage',
              stage = 'high')
# Out:
#                               sample_name  \
# 0  14521.006cdcd42d55e07a2fd1ad2d31dd1a87
# 1  14521.0337efea9b59b88f804ea384c356377c
# 2  14521.04a446c6a660694dafe43ccaf1db7162
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                              unknown                      relapse
# 1                                   no       no evidence of disease
# 2                              unknown                       stable
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    58.0                     58.0
# 1                    65.0                     65.0
# 2                    67.0                      NaN
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        58.0                 C15.5
# 1                        66.0                 C15.5
# 2                        68.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval  \
# 0                            299.0                   123.0
# 1                            712.0                     NaN
# 2                            401.0                     NaN
#
#               donor_relapse_type  ... donor_vital_status  \
# 0  distant recurrence/metastasis  ...           deceased
# 1                            NaN  ...           deceased
# 2                            NaN  ...              alive
#
#                                         filename icgc_donor_id icgc_sample_id  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam       DO50381       SA528854
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam       DO50389       SA528947
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam       DO50412       SA528884
#
#   prior_malignancy  project project_code qiita_study_id  \
# 0          unknown  ESAD-UK      ESAD-UK          14521
# 1          unknown  ESAD-UK      ESAD-UK          14521
# 2          unknown  ESAD-UK      ESAD-UK          14521
#
#   study_donor_involved_in submitted_donor_id
# 0                   PCAWG      OCCAMS-RS-031
# 1                   PCAWG      OCCAMS-SH-071
# 2                   PCAWG      OCCAMS-ZZ-019
#
# [3 rows x 25 columns]
# Total number of samples in EAC_species_WOL  =  98
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.006cdcd42d55e07a2fd1ad2d31dd1a87
# 1  14521.0337efea9b59b88f804ea384c356377c
# 2  14521.04a446c6a660694dafe43ccaf1db7162
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                              unknown                      relapse
# 1                                   no       no evidence of disease
# 2                              unknown                       stable
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    58.0                     58.0
# 1                    65.0                     65.0
# 2                    67.0                      NaN
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        58.0                 C15.5
# 1                        66.0                 C15.5
# 2                        68.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval  \
# 0                            299.0                   123.0
# 1                            712.0                     NaN
# 2                            401.0                     NaN
#
#               donor_relapse_type  ... donor_vital_status  \
# 0  distant recurrence/metastasis  ...           deceased
# 1                            NaN  ...           deceased
# 2                            NaN  ...              alive
#
#                                         filename icgc_donor_id icgc_sample_id  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam       DO50381       SA528854
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam       DO50389       SA528947
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam       DO50412       SA528884
#
#   prior_malignancy  project project_code qiita_study_id  \
# 0          unknown  ESAD-UK      ESAD-UK          14521
# 1          unknown  ESAD-UK      ESAD-UK          14521
# 2          unknown  ESAD-UK      ESAD-UK          14521
#
#   study_donor_involved_in submitted_donor_id
# 0                   PCAWG      OCCAMS-RS-031
# 1                   PCAWG      OCCAMS-SH-071
# 2                   PCAWG      OCCAMS-ZZ-019
#
# [3 rows x 25 columns]
# Total number of samples in EAC_genome_WOL  =  98
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.006cdcd42d55e07a2fd1ad2d31dd1a87
# 1  14521.0337efea9b59b88f804ea384c356377c
# 2  14521.04a446c6a660694dafe43ccaf1db7162
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                              unknown                      relapse
# 1                                   no       no evidence of disease
# 2                              unknown                       stable
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    58.0                     58.0
# 1                    65.0                     65.0
# 2                    67.0                      NaN
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        58.0                 C15.5
# 1                        66.0                 C15.5
# 2                        68.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval  \
# 0                            299.0                   123.0
# 1                            712.0                     NaN
# 2                            401.0                     NaN
#
#               donor_relapse_type  ... donor_vital_status  \
# 0  distant recurrence/metastasis  ...           deceased
# 1                            NaN  ...           deceased
# 2                            NaN  ...              alive
#
#                                         filename icgc_donor_id icgc_sample_id  \
# 0  006cdcd42d55e07a2fd1ad2d31dd1a87.filtered.bam       DO50381       SA528854
# 1  0337efea9b59b88f804ea384c356377c.filtered.bam       DO50389       SA528947
# 2  04a446c6a660694dafe43ccaf1db7162.filtered.bam       DO50412       SA528884
#
#   prior_malignancy  project project_code qiita_study_id  \
# 0          unknown  ESAD-UK      ESAD-UK          14521
# 1          unknown  ESAD-UK      ESAD-UK          14521
# 2          unknown  ESAD-UK      ESAD-UK          14521
#
#   study_donor_involved_in submitted_donor_id
# 0                   PCAWG      OCCAMS-RS-031
# 1                   PCAWG      OCCAMS-SH-071
# 2                   PCAWG      OCCAMS-ZZ-019
#
# [3 rows x 25 columns]
# Total number of samples in EAC_zebra_genome_WOL  =  98
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                                sample_name  \
# 48  14521.3756a5bb0047504a87838271674b6424
# 27  14521.18b320f63f6c5dd2dd4e0c30c87a1ce9
# 79  14521.5d003d442dbaf291b70d2d8a85db9670
#
#    cancer_history_first_degree_relative disease_status_last_followup  \
# 48                                  yes                       stable
# 27                              unknown       no evidence of disease
# 79                                   no                       stable
#
#     donor_age_at_diagnosis  donor_age_at_enrollment  \
# 48                    60.0                     60.0
# 27                    75.0                     75.0
# 79                    50.0                     50.0
#
#     donor_age_at_last_followup donor_diagnosis_icd10  \
# 48                        63.0                 C15.5
# 27                        77.0                 C15.5
# 79                        50.0                 C15.5
#
#     donor_interval_of_last_followup  donor_relapse_interval  \
# 48                           1262.0                     NaN
# 27                           1003.0                     NaN
# 79                            239.0                    79.0
#
#    donor_relapse_type  ... donor_vital_status  \
# 48                NaN  ...           deceased
# 27                NaN  ...              alive
# 79                NaN  ...           deceased
#
#                                          filename icgc_donor_id  \
# 48  3756a5bb0047504a87838271674b6424.filtered.bam       DO50441
# 27  18b320f63f6c5dd2dd4e0c30c87a1ce9.filtered.bam       DO50434
# 79  5d003d442dbaf291b70d2d8a85db9670.filtered.bam       DO50402
#
#    icgc_sample_id prior_malignancy  project project_code qiita_study_id  \
# 48       SA528993          unknown  ESAD-UK      ESAD-UK          14521
# 27       SA528916          unknown  ESAD-UK      ESAD-UK          14521
# 79       SA528872          unknown  ESAD-UK      ESAD-UK          14521
#
#    study_donor_involved_in submitted_donor_id
# 48                   PCAWG      OCCAMS-AH-174
# 27                   PCAWG      OCCAMS-AH-061
# 79                   PCAWG      OCCAMS-WG-002
#
# [3 rows x 25 columns]
# Total number of samples in EAC_species_23_WOL  =  24
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                                 sample_name  \
# 95   14521.706e8a8516284214f76ba9a63b61697d
# 27   14521.18b320f63f6c5dd2dd4e0c30c87a1ce9
# 165  14521.d073e37c97d855da5783148477977ec5
#
#     cancer_history_first_degree_relative disease_status_last_followup  \
# 95                               unknown                       stable
# 27                               unknown       no evidence of disease
# 165                                  yes       no evidence of disease
#
#      donor_age_at_diagnosis  donor_age_at_enrollment  \
# 95                     57.0                     57.0
# 27                     75.0                     75.0
# 165                    79.0                     79.0
#
#      donor_age_at_last_followup donor_diagnosis_icd10  \
# 95                         59.0                 C15.5
# 27                         77.0                 C15.5
# 165                        81.0                 C15.5
#
#      donor_interval_of_last_followup  donor_relapse_interval  \
# 95                            1059.0                     NaN
# 27                            1003.0                     NaN
# 165                            860.0                     NaN
#
#     donor_relapse_type  ... donor_vital_status  \
# 95                 NaN  ...              alive
# 27                 NaN  ...              alive
# 165                NaN  ...              alive
#
#                                           filename icgc_donor_id  \
# 95   706e8a8516284214f76ba9a63b61697d.filtered.bam       DO50408
# 27   18b320f63f6c5dd2dd4e0c30c87a1ce9.filtered.bam       DO50434
# 165  d073e37c97d855da5783148477977ec5.filtered.bam       DO50445
#
#     icgc_sample_id prior_malignancy  project project_code qiita_study_id  \
# 95        SA528878          unknown  ESAD-UK      ESAD-UK          14521
# 27        SA528916          unknown  ESAD-UK      ESAD-UK          14521
# 165       SA528928          unknown  ESAD-UK      ESAD-UK          14521
#
#     study_donor_involved_in submitted_donor_id
# 95                    PCAWG      OCCAMS-WG-019
# 27                    PCAWG      OCCAMS-AH-061
# 165                   PCAWG      OCCAMS-ED-036
#
# [3 rows x 25 columns]
# Total number of samples in EAC_genome_zebra_23_WOL  =  26
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.04ceb5f141916f7fc091a5e0aa51ada3
# 1  14521.08f6c8561dcbc9c4e311cc79d87c73fa
# 2  14521.0b7983f4d85911b7351f5136819c96f1
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                                   no       no evidence of disease
# 1                                  yes                       stable
# 2                                  yes                       stable
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    74.0                     74.0
# 1                    53.0                     53.0
# 2                    56.0                     56.0
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        76.0                 C15.5
# 1                        57.0                 C15.5
# 2                        60.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval donor_relapse_type  \
# 0                            767.0                     NaN                NaN
# 1                           1771.0                     NaN                NaN
# 2                           1473.0                     NaN                NaN
#
#    ... tumour_histological_type  tumour_grading_system tumour_grade  \
# 0  ...                   8140/3               standard          2.0
# 1  ...                   8140/3               standard          2.0
# 2  ...                   8140/3               standard          2.0
#
#   tumour_grade_supplemental tumour_stage_system tumour_stage  \
# 0                       NaN                TNM7       T2N0M0
# 1                       NaN                TNM7       T4aN0M
# 2                       NaN                TNM7       T3N0M0
#
#   tumour_stage_supplemental digital_image_of_stained_section  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
#
#   percentage_cellularity level_of_cellularity
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
#
# [3 rows x 54 columns]
# Total number of samples in EAC_genome_WOL_lowStage  =  16
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.0337efea9b59b88f804ea384c356377c
# 1  14521.066f8f871be1147c121d60aa552efad0
# 2  14521.0a250b03103541ef9137514aa0ac5af0
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                                   no       no evidence of disease
# 1                              unknown                       stable
# 2                              unknown       no evidence of disease
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    65.0                     65.0
# 1                    67.0                     67.0
# 2                    73.0                     73.0
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        66.0                 C15.5
# 1                        72.0                 C15.5
# 2                        76.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval donor_relapse_type  \
# 0                            712.0                     NaN                NaN
# 1                           2162.0                     NaN                NaN
# 2                           1127.0                     NaN                NaN
#
#    ... tumour_histological_type  tumour_grading_system tumour_grade  \
# 0  ...                   8140/3               standard          3.0
# 1  ...                   8140/3               standard          3.0
# 2  ...                   8140/3               standard          3.0
#
#   tumour_grade_supplemental tumour_stage_system tumour_stage  \
# 0                       NaN                TNM7        T3N2M
# 1                       NaN                TNM7       T3N0M0
# 2                       NaN                TNM7        T3N1M
#
#   tumour_stage_supplemental digital_image_of_stained_section  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
#
#   percentage_cellularity level_of_cellularity
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
#
# [3 rows x 54 columns]
# Total number of samples in EAC_genome_WOL_highStage  =  16
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.04ceb5f141916f7fc091a5e0aa51ada3
# 1  14521.08f6c8561dcbc9c4e311cc79d87c73fa
# 2  14521.0b7983f4d85911b7351f5136819c96f1
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                                   no       no evidence of disease
# 1                                  yes                       stable
# 2                                  yes                       stable
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    74.0                     74.0
# 1                    53.0                     53.0
# 2                    56.0                     56.0
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        76.0                 C15.5
# 1                        57.0                 C15.5
# 2                        60.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval donor_relapse_type  \
# 0                            767.0                     NaN                NaN
# 1                           1771.0                     NaN                NaN
# 2                           1473.0                     NaN                NaN
#
#    ... tumour_histological_type  tumour_grading_system tumour_grade  \
# 0  ...                   8140/3               standard          2.0
# 1  ...                   8140/3               standard          2.0
# 2  ...                   8140/3               standard          2.0
#
#   tumour_grade_supplemental tumour_stage_system tumour_stage  \
# 0                       NaN                TNM7       T2N0M0
# 1                       NaN                TNM7       T4aN0M
# 2                       NaN                TNM7       T3N0M0
#
#   tumour_stage_supplemental digital_image_of_stained_section  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
#
#   percentage_cellularity level_of_cellularity
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
#
# [3 rows x 54 columns]
# Total number of samples in EAC_species_WOL_lowStage  =  16
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
#                               sample_name  \
# 0  14521.0337efea9b59b88f804ea384c356377c
# 1  14521.066f8f871be1147c121d60aa552efad0
# 2  14521.0a250b03103541ef9137514aa0ac5af0
#
#   cancer_history_first_degree_relative disease_status_last_followup  \
# 0                                   no       no evidence of disease
# 1                              unknown                       stable
# 2                              unknown       no evidence of disease
#
#    donor_age_at_diagnosis  donor_age_at_enrollment  \
# 0                    65.0                     65.0
# 1                    67.0                     67.0
# 2                    73.0                     73.0
#
#    donor_age_at_last_followup donor_diagnosis_icd10  \
# 0                        66.0                 C15.5
# 1                        72.0                 C15.5
# 2                        76.0                 C15.5
#
#    donor_interval_of_last_followup  donor_relapse_interval donor_relapse_type  \
# 0                            712.0                     NaN                NaN
# 1                           2162.0                     NaN                NaN
# 2                           1127.0                     NaN                NaN
#
#    ... tumour_histological_type  tumour_grading_system tumour_grade  \
# 0  ...                   8140/3               standard          3.0
# 1  ...                   8140/3               standard          3.0
# 2  ...                   8140/3               standard          3.0
#
#   tumour_grade_supplemental tumour_stage_system tumour_stage  \
# 0                       NaN                TNM7        T3N2M
# 1                       NaN                TNM7       T3N0M0
# 2                       NaN                TNM7        T3N1M
#
#   tumour_stage_supplemental digital_image_of_stained_section  \
# 0                       NaN                              NaN
# 1                       NaN                              NaN
# 2                       NaN                              NaN
#
#   percentage_cellularity level_of_cellularity
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
#
# [3 rows x 54 columns]
# Total number of samples in EAC_species_WOL_highStage  =  16
# /Users/cguccion/Dropbox/current_Summer23/ISMEJ_EsophModeling_Paper/Figures/comad_of_EAC_progression/python_scripts/import_split_biom.py:90: FutureWarning: The behavior of .astype from SparseDtype to a non-sparse dtype is deprecated. In a future version, this will return a non-sparse array with the requested dtype. To retain the old behavior, use `obj.astype(SparseDtype(dtype))`
#   df.to_csv(filename, sep = '\t')
# ()
